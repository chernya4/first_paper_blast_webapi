# %%
from urllib.request import urlopen
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from collections import defaultdict

# %% [markdown]
# ### Differences Between Two BLAST API Call Styles
#
# #### `...?name=2004ef&format=json`
#
# Used more for a general search and a light weight summary of your serached for transient.
#
# - **Purpose:** Search/filter endpoint — you can pass criteria like `name`, `ra`, `dec`, etc., and it returns **a list** (even if there’s just one match).
# - **Response type:** JSON array of transient dicts. You’d need to index `[0]` to get the first match.
#
# #### `/api/transient/get/2004ef?format=json`
#
# Returns the Full Science Payload according to the "Science payload Data Model" found in the following link:
#
# https://blast.readthedocs.io/en/stable/usage/web_api.html#api-all
#
# - **Response type:** A single JSON dict (no array).

# %%
# Fetch the transient
response = urlopen('https://blast.ncsa.illinois.edu/api/transient/?name=2004ef&format=json')
data = json.loads(response.read())

transient = data[0]  # unpack the first (and only) result

transient.keys()

print("\n--- Transient Information ---\n")

for key, value in transient.items():
    print(f"{key:30}: {value}")

print("\n--- Host Information ---\n")

for key, value in transient['host'].items():
    print(f"{key:30}: {value}")

print(len(transient.keys()), "keys in transient")
# Out:
# --- Transient Information ---
#
# id                            : 2624
# ra_deg                        : 340.54174583333327
# dec_deg                       : 19.994555555555557
# name                          : 2004ef
# public_timestamp              : None
# redshift                      : 0.03002
# spectroscopic_class           : SN Ia
# milkyway_dust_reddening       : 0.047228389531373975
# image_trim_status             : processed
# progress                      : 100
# software_version              : 1.2.0
# host                          : {'id': 12156, 'ra_deg': 340.54385948, 'dec_deg': 19.9969434, 'name': '2004ef', 'redshift': 0.030988, 'redshift_err': None, 'photometric_redshift': 0.01854147685274371, 'photometric_redshift_err': None, 'milkyway_dust_reddening': 0.04736369989812374, 'software_version': None}
#
# --- Host Information ---
#
# id                            : 12156
# ra_deg                        : 340.54385948
# dec_deg                       : 19.9969434
# name                          : 2004ef
# redshift                      : 0.030988
# redshift_err                  : None
# photometric_redshift          : 0.01854147685274371
# photometric_redshift_err      : None
# milkyway_dust_reddening       : 0.04736369989812374
# software_version              : None
# 12 keys in transient

# %%
url = 'https://blast.ncsa.illinois.edu/api/transient/get/2004ef?format=json'
payload = json.loads(urlopen(url).read())  # ← just one dict
print(type(payload)) 
print(len(payload.keys()), "keys in payload")
for key, value in payload.items():
    print(f"{key:30}: {value}")
# Out:
# <class 'dict'>
# 621 keys in payload
# transient_id                  : 2624
# transient_ra_deg              : 340.54174583333327
# transient_dec_deg             : 19.994555555555557
# transient_name                : 2004ef
# transient_public_timestamp    : None
# transient_redshift            : 0.03002
# transient_spectroscopic_class : SN Ia
# transient_milkyway_dust_reddening: 0.047228389531373975
# transient_image_trim_status   : processed
# transient_progress            : 100
# transient_software_version    : 1.2.0
# transient_host                : {'id': 12156, 'ra_deg': 340.54385948, 'dec_deg': 19.9969434, 'name': '2004ef', 'redshift': 0.030988, 'redshift_err': None, 'photometric_redshift': 0.01854147685274371, 'photometric_redshift_err': None, 'milkyway_dust_reddening': 0.04736369989812374, 'software_version': None}
# host_name                     : 2004ef
# host_ra_deg                   : 340.54385948
# host_dec_deg                  : 19.9969434
# host_redshift                 : 0.030988
# host_milkyway_dust_reddening  : 0.04736369989812374
# local_aperture_id             : 115459
# local_aperture_ra_deg         : 340.54174583333327
# local_aperture_dec_deg        : 19.994555555555557
# local_aperture_name           : 2004ef_local
# local_aperture_orientation_deg: 0.0
# local_aperture_semi_major_axis_arcsec: 3.228509892904693
# local_aperture_semi_minor_axis_arcsec: 3.228509892904693
# local_aperture_type           : local
# local_aperture_software_version: None
# local_aperture_cutout         : None
# local_aperture_transient      : {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_id            : None
# global_aperture_ra_deg        : None
# global_aperture_dec_deg       : None
# global_aperture_name          : None
# global_aperture_orientation_deg: None
# global_aperture_semi_major_axis_arcsec: None
# global_aperture_semi_minor_axis_arcsec: None
# global_aperture_type          : None
# global_aperture_software_version: None
# global_aperture_cutout        : None
# global_aperture_transient     : None
# local_aperture_2MASS_H_id     : 201381
# local_aperture_2MASS_H_flux   : 593.734367144609
# local_aperture_2MASS_H_flux_error: 96.26393873523152
# local_aperture_2MASS_H_magnitude: 15.598419530163845
# local_aperture_2MASS_H_magnitude_error: 0.17602780648772126
# local_aperture_2MASS_H_is_validated: true
# local_aperture_2MASS_H_software_version: None
# local_aperture_2MASS_H_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_2MASS_H_filter : {'id': 1, 'name': '2MASS_H', 'kcorrect_name': 'twomass_H', 'sedpy_id': 'twomass_H', 'hips_id': 'CDS/P/2MASS/H', 'vosa_id': '2MASS/2MASS.H', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.0, 'image_fwhm_arcsec': 2.8, 'wavelength_eff_angstrom': 16620.0, 'wavelength_min_angstrom': 14787.38, 'wavelength_max_angstrom': 18231.02, 'vega_zero_point_jansky': 1024.0, 'magnitude_zero_point': None, 'ab_offset': 1.3676, 'magnitude_zero_point_keyword': 'MAGZP', 'image_pixel_units': 'counts', 'survey': 1}
# local_aperture_2MASS_H_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_2MASS_J_id     : 201382
# local_aperture_2MASS_J_flux   : 503.94834086101116
# local_aperture_2MASS_J_flux_error: 74.67168403142915
# local_aperture_2MASS_J_magnitude: 16.249134950696057
# local_aperture_2MASS_J_magnitude_error: 0.1608717417630749
# local_aperture_2MASS_J_is_validated: true
# local_aperture_2MASS_J_software_version: None
# local_aperture_2MASS_J_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_2MASS_J_filter : {'id': 2, 'name': '2MASS_J', 'kcorrect_name': 'twomass_J', 'sedpy_id': 'twomass_j', 'hips_id': 'CDS/P/2MASS/J', 'vosa_id': '2MASS/2MASS.J', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.0, 'image_fwhm_arcsec': 2.9, 'wavelength_eff_angstrom': 12350.0, 'wavelength_min_angstrom': 10806.47, 'wavelength_max_angstrom': 14067.97, 'vega_zero_point_jansky': 1594.0, 'magnitude_zero_point': None, 'ab_offset': 0.8949, 'magnitude_zero_point_keyword': 'MAGZP', 'image_pixel_units': 'counts', 'survey': 1}
# local_aperture_2MASS_J_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_2MASS_K_id     : 201384
# local_aperture_2MASS_K_flux   : 366.9818265372952
# local_aperture_2MASS_K_flux_error: 149.99879717485777
# local_aperture_2MASS_K_magnitude: 15.650588605241667
# local_aperture_2MASS_K_magnitude_error: 0.4437650104621537
# local_aperture_2MASS_K_is_validated: true
# local_aperture_2MASS_K_software_version: None
# local_aperture_2MASS_K_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_2MASS_K_filter : {'id': 3, 'name': '2MASS_K', 'kcorrect_name': 'twomass_Ks', 'sedpy_id': 'twomass_k', 'hips_id': 'CDS/P/2MASS/K', 'vosa_id': '2MASS/2MASS.Ks', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.0, 'image_fwhm_arcsec': 2.9, 'wavelength_eff_angstrom': 21590.0, 'wavelength_min_angstrom': 19543.69, 'wavelength_max_angstrom': 23552.4, 'vega_zero_point_jansky': 666.8, 'magnitude_zero_point': None, 'ab_offset': 1.8378, 'magnitude_zero_point_keyword': 'MAGZP', 'image_pixel_units': 'counts', 'survey': 1}
# local_aperture_2MASS_K_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_WISE_W1_id     : 201385
# local_aperture_WISE_W1_flux   : 23.639884776216164
# local_aperture_WISE_W1_flux_error: 4.263168350484064
# local_aperture_WISE_W1_magnitude: 17.766886611479435
# local_aperture_WISE_W1_magnitude_error: 0.19579291193404022
# local_aperture_WISE_W1_is_validated: false
# local_aperture_WISE_W1_software_version: None
# local_aperture_WISE_W1_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_WISE_W1_filter : {'id': 4, 'name': 'WISE_W1', 'kcorrect_name': 'wise_w1', 'sedpy_id': 'wise_w1', 'hips_id': 'CDS/P/allWISE/W1', 'vosa_id': 'WISE/WISE.W1', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.375, 'image_fwhm_arcsec': 5.84, 'wavelength_eff_angstrom': 33526.0, 'wavelength_min_angstrom': 27540.97, 'wavelength_max_angstrom': 38723.88, 'vega_zero_point_jansky': 309.54, 'magnitude_zero_point': 20.5, 'ab_offset': 2.699, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 2}
# local_aperture_WISE_W1_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_WISE_W2_id     : 201387
# local_aperture_WISE_W2_flux   : 12.430960902231401
# local_aperture_WISE_W2_flux_error: 6.816655144920318
# local_aperture_WISE_W2_magnitude: 17.824738248708172
# local_aperture_WISE_W2_magnitude_error: 0.5953556244804465
# local_aperture_WISE_W2_is_validated: false
# local_aperture_WISE_W2_software_version: None
# local_aperture_WISE_W2_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_WISE_W2_filter : {'id': 5, 'name': 'WISE_W2', 'kcorrect_name': 'wise_w2', 'sedpy_id': 'wise_w2', 'hips_id': 'CDS/P/allWISE/W2', 'vosa_id': 'WISE/WISE.W2', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.375, 'image_fwhm_arcsec': 6.48, 'wavelength_eff_angstrom': 46028.0, 'wavelength_min_angstrom': 39633.26, 'wavelength_max_angstrom': 53413.6, 'vega_zero_point_jansky': 171.79, 'magnitude_zero_point': 19.5, 'ab_offset': 3.339, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 2}
# local_aperture_WISE_W2_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_WISE_W3_id     : 201388
# local_aperture_WISE_W3_flux   : -8.51384904282827
# local_aperture_WISE_W3_flux_error: 28.48127352396967
# local_aperture_WISE_W3_magnitude: None
# local_aperture_WISE_W3_magnitude_error: None
# local_aperture_WISE_W3_is_validated: false
# local_aperture_WISE_W3_software_version: None
# local_aperture_WISE_W3_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_WISE_W3_filter : {'id': 6, 'name': 'WISE_W3', 'kcorrect_name': 'wise_w3', 'sedpy_id': 'wise_w3', 'hips_id': 'CDS/P/allWISE/W3', 'vosa_id': 'WISE/WISE.W3', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.375, 'image_fwhm_arcsec': 6.72, 'wavelength_eff_angstrom': 115608.0, 'wavelength_min_angstrom': 74430.44, 'wavelength_max_angstrom': 172613.43, 'vega_zero_point_jansky': 31.67, 'magnitude_zero_point': 18.0, 'ab_offset': 5.174, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 2}
# local_aperture_WISE_W3_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_WISE_W4_id     : 201391
# local_aperture_WISE_W4_flux   : 4.5729848144661664
# local_aperture_WISE_W4_flux_error: 51.2706047887877
# local_aperture_WISE_W4_magnitude: 15.62950060195202
# local_aperture_WISE_W4_magnitude_error: 12.172464566927472
# local_aperture_WISE_W4_is_validated: false
# local_aperture_WISE_W4_software_version: None
# local_aperture_WISE_W4_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_WISE_W4_filter : {'id': 7, 'name': 'WISE_W4', 'kcorrect_name': 'wise_w4', 'sedpy_id': 'wise_w4', 'hips_id': 'CDS/P/allWISE/W4', 'vosa_id': 'WISE/WISE.W4', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.375, 'image_fwhm_arcsec': 11.82, 'wavelength_eff_angstrom': 220883.0, 'wavelength_min_angstrom': 195200.83, 'wavelength_max_angstrom': 279107.24, 'vega_zero_point_jansky': 8.36, 'magnitude_zero_point': 13.0, 'ab_offset': 6.62, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 2}
# local_aperture_WISE_W4_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_GALEX_NUV_id   : 201392
# local_aperture_GALEX_NUV_flux : 4.497313745290325
# local_aperture_GALEX_NUV_flux_error: 0.40483483218930766
# local_aperture_GALEX_NUV_magnitude: 22.267617034418294
# local_aperture_GALEX_NUV_magnitude_error: 0.09773149088569037
# local_aperture_GALEX_NUV_is_validated: false
# local_aperture_GALEX_NUV_software_version: None
# local_aperture_GALEX_NUV_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_GALEX_NUV_filter: {'id': 8, 'name': 'GALEX_NUV', 'kcorrect_name': 'galex_NUV', 'sedpy_id': 'galex_nuv', 'hips_id': 'CDS/P/GALEXGR6/AIS/NUV', 'vosa_id': 'GALEX/GALEX.NUV', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.5, 'image_fwhm_arcsec': 5.3, 'wavelength_eff_angstrom': 2304.74, 'wavelength_min_angstrom': 1692.52, 'wavelength_max_angstrom': 3006.67, 'vega_zero_point_jansky': 788.55, 'magnitude_zero_point': 20.08, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 3}
# local_aperture_GALEX_NUV_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_GALEX_FUV_id   : 201393
# local_aperture_GALEX_FUV_flux : 2.335172831443724
# local_aperture_GALEX_FUV_flux_error: 1.292275456128727
# local_aperture_GALEX_FUV_magnitude: 22.9792024269689
# local_aperture_GALEX_FUV_magnitude_error: 0.6008221078229733
# local_aperture_GALEX_FUV_is_validated: false
# local_aperture_GALEX_FUV_software_version: None
# local_aperture_GALEX_FUV_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_GALEX_FUV_filter: {'id': 9, 'name': 'GALEX_FUV', 'kcorrect_name': 'galex_FUV', 'sedpy_id': 'galex_fuv', 'hips_id': 'CDS/P/GALEXGR6/AIS/FUV', 'vosa_id': 'GALEX/GALEX.FUV', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.5, 'image_fwhm_arcsec': 4.2, 'wavelength_eff_angstrom': 1549.02, 'wavelength_min_angstrom': 1340.32, 'wavelength_max_angstrom': 1806.43, 'vega_zero_point_jansky': 520.73, 'magnitude_zero_point': 18.82, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 3}
# local_aperture_GALEX_FUV_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_PanSTARRS_g_id : 201408
# local_aperture_PanSTARRS_g_flux: 97.22101736402877
# local_aperture_PanSTARRS_g_flux_error: 0.835282308669965
# local_aperture_PanSTARRS_g_magnitude: 18.930599596467
# local_aperture_PanSTARRS_g_magnitude_error: 0.00932788019618602
# local_aperture_PanSTARRS_g_is_validated: true
# local_aperture_PanSTARRS_g_software_version: None
# local_aperture_PanSTARRS_g_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_PanSTARRS_g_filter: {'id': 10, 'name': 'PanSTARRS_g', 'kcorrect_name': 'none', 'sedpy_id': 'panstarrs_g', 'hips_id': 'CDS/P/PanSTARRS/DR1/g', 'vosa_id': 'PAN-STARRS/PS1.g', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.25, 'image_fwhm_arcsec': 1.31, 'wavelength_eff_angstrom': 4810.88, 'wavelength_min_angstrom': 3943.4, 'wavelength_max_angstrom': 5593.27, 'vega_zero_point_jansky': 3893.0, 'magnitude_zero_point': 25.0, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts', 'survey': 4}
# local_aperture_PanSTARRS_g_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_PanSTARRS_r_id : 201423
# local_aperture_PanSTARRS_r_flux: 190.1279919586848
# local_aperture_PanSTARRS_r_flux_error: 1.0721067592074722
# local_aperture_PanSTARRS_r_magnitude: 18.202384846470665
# local_aperture_PanSTARRS_r_magnitude_error: 0.006122119612584397
# local_aperture_PanSTARRS_r_is_validated: true
# local_aperture_PanSTARRS_r_software_version: None
# local_aperture_PanSTARRS_r_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_PanSTARRS_r_filter: {'id': 11, 'name': 'PanSTARRS_r', 'kcorrect_name': 'none', 'sedpy_id': 'panstarrs_r', 'hips_id': 'CDS/P/PanSTARRS/DR1/r', 'vosa_id': 'PAN-STARRS/PS1.r', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.25, 'image_fwhm_arcsec': 1.19, 'wavelength_eff_angstrom': 6156.36, 'wavelength_min_angstrom': 5386.23, 'wavelength_max_angstrom': 7035.65, 'vega_zero_point_jansky': 3135.5, 'magnitude_zero_point': 25.0, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts', 'survey': 4}
# local_aperture_PanSTARRS_r_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_PanSTARRS_i_id : 201427
# local_aperture_PanSTARRS_i_flux: 266.1874566877798
# local_aperture_PanSTARRS_i_flux_error: 1.1348919875497383
# local_aperture_PanSTARRS_i_magnitude: 17.837031033119064
# local_aperture_PanSTARRS_i_magnitude_error: 0.004628889152834816
# local_aperture_PanSTARRS_i_is_validated: true
# local_aperture_PanSTARRS_i_software_version: None
# local_aperture_PanSTARRS_i_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_PanSTARRS_i_filter: {'id': 12, 'name': 'PanSTARRS_i', 'kcorrect_name': 'none', 'sedpy_id': 'panstarrs_i', 'hips_id': 'CDS/P/PanSTARRS/DR1/i', 'vosa_id': 'PAN-STARRS/PS1.i', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.25, 'image_fwhm_arcsec': 1.11, 'wavelength_eff_angstrom': 7503.68, 'wavelength_min_angstrom': 6778.45, 'wavelength_max_angstrom': 8304.37, 'vega_zero_point_jansky': 2577.03, 'magnitude_zero_point': 25.0, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts', 'survey': 4}
# local_aperture_PanSTARRS_i_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_PanSTARRS_z_id : 201435
# local_aperture_PanSTARRS_z_flux: 321.0903690205836
# local_aperture_PanSTARRS_z_flux_error: 2.5920531036466357
# local_aperture_PanSTARRS_z_magnitude: 17.633431801826067
# local_aperture_PanSTARRS_z_magnitude_error: 0.00876448603305429
# local_aperture_PanSTARRS_z_is_validated: true
# local_aperture_PanSTARRS_z_software_version: None
# local_aperture_PanSTARRS_z_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_PanSTARRS_z_filter: {'id': 13, 'name': 'PanSTARRS_z', 'kcorrect_name': 'none', 'sedpy_id': 'panstarrs_z', 'hips_id': 'CDS/P/PanSTARRS/DR1/z', 'vosa_id': 'PAN-STARRS/PS1.z', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.25, 'image_fwhm_arcsec': 1.07, 'wavelength_eff_angstrom': 8668.56, 'wavelength_min_angstrom': 8028.0, 'wavelength_max_angstrom': 9346.0, 'vega_zero_point_jansky': 2273.05, 'magnitude_zero_point': 25.0, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts', 'survey': 4}
# local_aperture_PanSTARRS_z_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_PanSTARRS_y_id : 201441
# local_aperture_PanSTARRS_y_flux: 388.32516901890074
# local_aperture_PanSTARRS_y_flux_error: 6.001990810692782
# local_aperture_PanSTARRS_y_magnitude: 17.42701115013642
# local_aperture_PanSTARRS_y_magnitude_error: 0.016780682641902068
# local_aperture_PanSTARRS_y_is_validated: true
# local_aperture_PanSTARRS_y_software_version: None
# local_aperture_PanSTARRS_y_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_PanSTARRS_y_filter: {'id': 14, 'name': 'PanSTARRS_y', 'kcorrect_name': 'none', 'sedpy_id': 'panstarrs_y', 'hips_id': 'CDS/P/PanSTARRS/DR1/y', 'vosa_id': 'PAN-STARRS/PS1.y', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.25, 'image_fwhm_arcsec': 1.02, 'wavelength_eff_angstrom': 9613.45, 'wavelength_min_angstrom': 9100.5, 'wavelength_max_angstrom': 10838.5, 'vega_zero_point_jansky': 2203.66, 'magnitude_zero_point': 25.0, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts', 'survey': 4}
# local_aperture_PanSTARRS_y_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_SDSS_i_id      : 201443
# local_aperture_SDSS_i_flux    : 258.1811210123663
# local_aperture_SDSS_i_flux_error: 5.072861007660366
# local_aperture_SDSS_i_magnitude: 17.870188794599976
# local_aperture_SDSS_i_magnitude_error: 0.021332331250328167
# local_aperture_SDSS_i_is_validated: true
# local_aperture_SDSS_i_software_version: None
# local_aperture_SDSS_i_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_SDSS_i_filter  : {'id': 15, 'name': 'SDSS_i', 'kcorrect_name': 'sdss_i0', 'sedpy_id': 'sdss_i', 'hips_id': 'CDS/P/SDSS9/i', 'vosa_id': 'SLOAN/SDSS.i', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.4, 'image_fwhm_arcsec': 1.26, 'wavelength_eff_angstrom': 7470.6, 'wavelength_min_angstrom': 6430.0, 'wavelength_max_angstrom': 8630.0, 'vega_zero_point_jansky': 3971.19, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 5}
# local_aperture_SDSS_i_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_SDSS_r_id      : 201445
# local_aperture_SDSS_r_flux    : 182.86049876832922
# local_aperture_SDSS_r_flux_error: 3.921303345138574
# local_aperture_SDSS_r_magnitude: 18.244700249973874
# local_aperture_SDSS_r_magnitude_error: 0.023282004973696972
# local_aperture_SDSS_r_is_validated: true
# local_aperture_SDSS_r_software_version: None
# local_aperture_SDSS_r_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_SDSS_r_filter  : {'id': 16, 'name': 'SDSS_r', 'kcorrect_name': 'sdss_r0', 'sedpy_id': 'sdss_r', 'hips_id': 'CDS/P/SDSS9/r', 'vosa_id': 'SLOAN/SDSS.r', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.4, 'image_fwhm_arcsec': 1.32, 'wavelength_eff_angstrom': 6141.12, 'wavelength_min_angstrom': 5415.34, 'wavelength_max_angstrom': 6989.14, 'vega_zero_point_jansky': 3142.02, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 5}
# local_aperture_SDSS_r_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_SDSS_u_id      : 201448
# local_aperture_SDSS_u_flux    : 20.872923199669078
# local_aperture_SDSS_u_flux_error: 2.825896150047631
# local_aperture_SDSS_u_magnitude: 20.601041812101045
# local_aperture_SDSS_u_magnitude_error: 0.14698829774620908
# local_aperture_SDSS_u_is_validated: true
# local_aperture_SDSS_u_software_version: None
# local_aperture_SDSS_u_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_SDSS_u_filter  : {'id': 17, 'name': 'SDSS_u', 'kcorrect_name': 'sdss_u0', 'sedpy_id': 'sdss_u', 'hips_id': 'CDS/P/SDSS9/u', 'vosa_id': 'SLOAN/SDSS.u', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.4, 'image_fwhm_arcsec': 1.53, 'wavelength_eff_angstrom': 3608.04, 'wavelength_min_angstrom': 3048.28, 'wavelength_max_angstrom': 4028.23, 'vega_zero_point_jansky': 1628.72, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 5}
# local_aperture_SDSS_u_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_SDSS_z_id      : 201454
# local_aperture_SDSS_z_flux    : 329.57255789148707
# local_aperture_SDSS_z_flux_error: 11.138491801139725
# local_aperture_SDSS_z_magnitude: 17.605122393320677
# local_aperture_SDSS_z_magnitude_error: 0.03669316591728819
# local_aperture_SDSS_z_is_validated: true
# local_aperture_SDSS_z_software_version: None
# local_aperture_SDSS_z_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_SDSS_z_filter  : {'id': 18, 'name': 'SDSS_z', 'kcorrect_name': 'sdss_z0', 'sedpy_id': 'sdss_z', 'hips_id': 'CDS/P/SDSS9/z', 'vosa_id': 'SLOAN/SDSS.z', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.4, 'image_fwhm_arcsec': 1.29, 'wavelength_eff_angstrom': 8922.78, 'wavelength_min_angstrom': 7960.44, 'wavelength_max_angstrom': 10833.25, 'vega_zero_point_jansky': 2227.03, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 5}
# local_aperture_SDSS_z_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_SDSS_g_id      : 201458
# local_aperture_SDSS_g_flux    : 88.47889754557397
# local_aperture_SDSS_g_flux_error: 2.669307983947151
# local_aperture_SDSS_g_magnitude: 19.032900743377617
# local_aperture_SDSS_g_magnitude_error: 0.03275433757160771
# local_aperture_SDSS_g_is_validated: true
# local_aperture_SDSS_g_software_version: None
# local_aperture_SDSS_g_aperture: {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_SDSS_g_filter  : {'id': 19, 'name': 'SDSS_g', 'kcorrect_name': 'sdss_g0', 'sedpy_id': 'sdss_g', 'hips_id': 'CDS/P/SDSS9/g', 'vosa_id': 'SLOAN/SDSS.g', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.4, 'image_fwhm_arcsec': 1.44, 'wavelength_eff_angstrom': 4671.78, 'wavelength_min_angstrom': 3797.64, 'wavelength_max_angstrom': 5553.04, 'vega_zero_point_jansky': 4023.57, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 5}
# local_aperture_SDSS_g_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_DES_g_id       : 201464
# local_aperture_DES_g_flux     : 102.14850683011849
# local_aperture_DES_g_flux_error: 0.5858827984158991
# local_aperture_DES_g_magnitude: 18.876919943361496
# local_aperture_DES_g_magnitude_error: 0.006227139034915287
# local_aperture_DES_g_is_validated: true
# local_aperture_DES_g_software_version: None
# local_aperture_DES_g_aperture : {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_DES_g_filter   : {'id': 20, 'name': 'DES_g', 'kcorrect_name': 'decam_g', 'sedpy_id': 'des_g', 'hips_id': 'CDS/P/DES-DR1/g', 'vosa_id': 'CTIO/DECam.g', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.2637, 'image_fwhm_arcsec': 1.16, 'wavelength_eff_angstrom': 4770.83, 'wavelength_min_angstrom': 3925.42, 'wavelength_max_angstrom': 5529.96, 'vega_zero_point_jansky': 3905.01, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 6}
# local_aperture_DES_g_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_DES_r_id       : 201476
# local_aperture_DES_r_flux     : 209.84181827971454
# local_aperture_DES_r_flux_error: 1.5764436746613546
# local_aperture_DES_r_magnitude: 18.095269898097424
# local_aperture_DES_r_magnitude_error: 0.008156357544035294
# local_aperture_DES_r_is_validated: true
# local_aperture_DES_r_software_version: None
# local_aperture_DES_r_aperture : {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_DES_r_filter   : {'id': 21, 'name': 'DES_r', 'kcorrect_name': 'decam_r', 'sedpy_id': 'des_r', 'hips_id': 'CDS/P/DES-DR1/r', 'vosa_id': 'CTIO/DECam.r', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.2637, 'image_fwhm_arcsec': 1.07, 'wavelength_eff_angstrom': 6371.33, 'wavelength_min_angstrom': 5519.97, 'wavelength_max_angstrom': 7233.72, 'vega_zero_point_jansky': 3027.32, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 6}
# local_aperture_DES_r_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_DES_i_id       : None
# local_aperture_DES_i_flux     : None
# local_aperture_DES_i_flux_error: None
# local_aperture_DES_i_magnitude: None
# local_aperture_DES_i_magnitude_error: None
# local_aperture_DES_i_is_validated: None
# local_aperture_DES_i_software_version: None
# local_aperture_DES_i_aperture : None
# local_aperture_DES_i_filter   : None
# local_aperture_DES_i_transient: None
# local_aperture_DES_z_id       : 201484
# local_aperture_DES_z_flux     : 361.72261977909847
# local_aperture_DES_z_flux_error: 4.04693974900769
# local_aperture_DES_z_magnitude: 17.50406083109509
# local_aperture_DES_z_magnitude_error: 0.012146772817748832
# local_aperture_DES_z_is_validated: true
# local_aperture_DES_z_software_version: None
# local_aperture_DES_z_aperture : {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# local_aperture_DES_z_filter   : {'id': 23, 'name': 'DES_z', 'kcorrect_name': 'decam_z', 'sedpy_id': 'des_z', 'hips_id': 'CDS/P/DES-DR1/z', 'vosa_id': 'CTIO/DECam.z', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.2637, 'image_fwhm_arcsec': 0.93, 'wavelength_eff_angstrom': 9157.9, 'wavelength_min_angstrom': 8341.2, 'wavelength_max_angstrom': 10074.26, 'vega_zero_point_jansky': 2247.33, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 6}
# local_aperture_DES_z_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_DES_Y_id       : None
# local_aperture_DES_Y_flux     : None
# local_aperture_DES_Y_flux_error: None
# local_aperture_DES_Y_magnitude: None
# local_aperture_DES_Y_magnitude_error: None
# local_aperture_DES_Y_is_validated: None
# local_aperture_DES_Y_software_version: None
# local_aperture_DES_Y_aperture : None
# local_aperture_DES_Y_filter   : None
# local_aperture_DES_Y_transient: None
# global_aperture_2MASS_H_id    : 205613
# global_aperture_2MASS_H_flux  : 33704.66960981181
# global_aperture_2MASS_H_flux_error: 1087.9307549543419
# global_aperture_2MASS_H_magnitude: 11.213174814195252
# global_aperture_2MASS_H_magnitude_error: 0.03504459276200939
# global_aperture_2MASS_H_is_validated: false
# global_aperture_2MASS_H_software_version: None
# global_aperture_2MASS_H_aperture: {'id': 117687, 'ra_deg': 340.54377179750253, 'dec_deg': 19.996990330798187, 'name': '2004ef_2MASS_H_global', 'orientation_deg': -21.278787865892244, 'semi_major_axis_arcsec': 37.66983094996157, 'semi_minor_axis_arcsec': 35.46238007047011, 'type': 'global', 'software_version': None, 'cutout': 37423, 'transient': 2624}
# global_aperture_2MASS_H_filter: {'id': 1, 'name': '2MASS_H', 'kcorrect_name': 'twomass_H', 'sedpy_id': 'twomass_H', 'hips_id': 'CDS/P/2MASS/H', 'vosa_id': '2MASS/2MASS.H', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.0, 'image_fwhm_arcsec': 2.8, 'wavelength_eff_angstrom': 16620.0, 'wavelength_min_angstrom': 14787.38, 'wavelength_max_angstrom': 18231.02, 'vega_zero_point_jansky': 1024.0, 'magnitude_zero_point': None, 'ab_offset': 1.3676, 'magnitude_zero_point_keyword': 'MAGZP', 'image_pixel_units': 'counts', 'survey': 1}
# global_aperture_2MASS_H_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_2MASS_J_id    : 205615
# global_aperture_2MASS_J_flux  : 27792.190001027186
# global_aperture_2MASS_J_flux_error: 845.0100460610419
# global_aperture_2MASS_J_magnitude: 11.895293074592432
# global_aperture_2MASS_J_magnitude_error: 0.03301025960798935
# global_aperture_2MASS_J_is_validated: true
# global_aperture_2MASS_J_software_version: None
# global_aperture_2MASS_J_aperture: {'id': 117692, 'ra_deg': 340.54377179750253, 'dec_deg': 19.996990330798187, 'name': '2004ef_2MASS_J_global', 'orientation_deg': -21.278787865892244, 'semi_major_axis_arcsec': 37.76983094996157, 'semi_minor_axis_arcsec': 35.56238007047011, 'type': 'global', 'software_version': None, 'cutout': 37429, 'transient': 2624}
# global_aperture_2MASS_J_filter: {'id': 2, 'name': '2MASS_J', 'kcorrect_name': 'twomass_J', 'sedpy_id': 'twomass_j', 'hips_id': 'CDS/P/2MASS/J', 'vosa_id': '2MASS/2MASS.J', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.0, 'image_fwhm_arcsec': 2.9, 'wavelength_eff_angstrom': 12350.0, 'wavelength_min_angstrom': 10806.47, 'wavelength_max_angstrom': 14067.97, 'vega_zero_point_jansky': 1594.0, 'magnitude_zero_point': None, 'ab_offset': 0.8949, 'magnitude_zero_point_keyword': 'MAGZP', 'image_pixel_units': 'counts', 'survey': 1}
# global_aperture_2MASS_J_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_2MASS_K_id    : 205618
# global_aperture_2MASS_K_flux  : 24786.88183296343
# global_aperture_2MASS_K_flux_error: 1702.0422905299995
# global_aperture_2MASS_K_magnitude: 11.076645259110377
# global_aperture_2MASS_K_magnitude_error: 0.0745518265379769
# global_aperture_2MASS_K_is_validated: true
# global_aperture_2MASS_K_software_version: None
# global_aperture_2MASS_K_aperture: {'id': 117694, 'ra_deg': 340.54377179750253, 'dec_deg': 19.996990330798187, 'name': '2004ef_2MASS_K_global', 'orientation_deg': -21.278787865892244, 'semi_major_axis_arcsec': 37.76983094996157, 'semi_minor_axis_arcsec': 35.56238007047011, 'type': 'global', 'software_version': None, 'cutout': 37432, 'transient': 2624}
# global_aperture_2MASS_K_filter: {'id': 3, 'name': '2MASS_K', 'kcorrect_name': 'twomass_Ks', 'sedpy_id': 'twomass_k', 'hips_id': 'CDS/P/2MASS/K', 'vosa_id': '2MASS/2MASS.Ks', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.0, 'image_fwhm_arcsec': 2.9, 'wavelength_eff_angstrom': 21590.0, 'wavelength_min_angstrom': 19543.69, 'wavelength_max_angstrom': 23552.4, 'vega_zero_point_jansky': 666.8, 'magnitude_zero_point': None, 'ab_offset': 1.8378, 'magnitude_zero_point_keyword': 'MAGZP', 'image_pixel_units': 'counts', 'survey': 1}
# global_aperture_2MASS_K_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_WISE_W1_id    : 205619
# global_aperture_WISE_W1_flux  : 15500.435811261541
# global_aperture_WISE_W1_flux_error: 116.11832909084148
# global_aperture_WISE_W1_magnitude: 10.725140227515361
# global_aperture_WISE_W1_magnitude_error: 0.00813329840715402
# global_aperture_WISE_W1_is_validated: true
# global_aperture_WISE_W1_software_version: None
# global_aperture_WISE_W1_aperture: {'id': 117696, 'ra_deg': 340.54377179750253, 'dec_deg': 19.996990330798187, 'name': '2004ef_WISE_W1_global', 'orientation_deg': -21.278787865892244, 'semi_major_axis_arcsec': 40.70983094996157, 'semi_minor_axis_arcsec': 38.50238007047011, 'type': 'global', 'software_version': None, 'cutout': 37438, 'transient': 2624}
# global_aperture_WISE_W1_filter: {'id': 4, 'name': 'WISE_W1', 'kcorrect_name': 'wise_w1', 'sedpy_id': 'wise_w1', 'hips_id': 'CDS/P/allWISE/W1', 'vosa_id': 'WISE/WISE.W1', 'image_download_method': 'custom', 'pixel_size_arcsec': 1.375, 'image_fwhm_arcsec': 5.84, 'wavelength_eff_angstrom': 33526.0, 'wavelength_min_angstrom': 27540.97, 'wavelength_max_angstrom': 38723.88, 'vega_zero_point_jansky': 309.54, 'magnitude_zero_point': 20.5, 'ab_offset': 2.699, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 2}
# global_aperture_WISE_W1_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_WISE_W2_id    : 205621
# global_aperture_WISE_W2_flux  : 8036.379021378475
# global_aperture_WISE_W2_flux_error: 165.34923508150226
# global_aperture_WISE_W2_magnitude: 10.798348971804417
# global_aperture_WISE_W2_magnitude_error: 0.022338377029060795
# global_aperture_WISE_W2_is_validated: false
# global_aperture_WISE_W2_software_version: None
# ...
# global_aperture_DES_g_filter  : {'id': 20, 'name': 'DES_g', 'kcorrect_name': 'decam_g', 'sedpy_id': 'des_g', 'hips_id': 'CDS/P/DES-DR1/g', 'vosa_id': 'CTIO/DECam.g', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.2637, 'image_fwhm_arcsec': 1.16, 'wavelength_eff_angstrom': 4770.83, 'wavelength_min_angstrom': 3925.42, 'wavelength_max_angstrom': 5529.96, 'vega_zero_point_jansky': 3905.01, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 6}
# global_aperture_DES_g_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_DES_r_id      : 205674
# global_aperture_DES_r_flux    : 13095.825780914398
# global_aperture_DES_r_flux_error: 13.377083227880162
# global_aperture_DES_r_magnitude: 13.607167777883612
# global_aperture_DES_r_magnitude_error: 0.0011090174459770044
# global_aperture_DES_r_is_validated: false
# global_aperture_DES_r_software_version: None
# global_aperture_DES_r_aperture: {'id': 117749, 'ra_deg': 340.54377179750253, 'dec_deg': 19.996990330798187, 'name': '2004ef_DES_r_global', 'orientation_deg': -21.278787865892244, 'semi_major_axis_arcsec': 35.93983094996157, 'semi_minor_axis_arcsec': 33.73238007047011, 'type': 'global', 'software_version': None, 'cutout': 37642, 'transient': 2624}
# global_aperture_DES_r_filter  : {'id': 21, 'name': 'DES_r', 'kcorrect_name': 'decam_r', 'sedpy_id': 'des_r', 'hips_id': 'CDS/P/DES-DR1/r', 'vosa_id': 'CTIO/DECam.r', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.2637, 'image_fwhm_arcsec': 1.07, 'wavelength_eff_angstrom': 6371.33, 'wavelength_min_angstrom': 5519.97, 'wavelength_max_angstrom': 7233.72, 'vega_zero_point_jansky': 3027.32, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 6}
# global_aperture_DES_r_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_DES_i_id      : None
# global_aperture_DES_i_flux    : None
# global_aperture_DES_i_flux_error: None
# global_aperture_DES_i_magnitude: None
# global_aperture_DES_i_magnitude_error: None
# global_aperture_DES_i_is_validated: None
# global_aperture_DES_i_software_version: None
# global_aperture_DES_i_aperture: None
# global_aperture_DES_i_filter  : None
# global_aperture_DES_i_transient: None
# global_aperture_DES_z_id      : 205678
# global_aperture_DES_z_flux    : 21612.313958029543
# global_aperture_DES_z_flux_error: 32.40344121465307
# global_aperture_DES_z_magnitude: 13.063246830431423
# global_aperture_DES_z_magnitude_error: 0.0016277949781346012
# global_aperture_DES_z_is_validated: false
# global_aperture_DES_z_software_version: None
# global_aperture_DES_z_aperture: {'id': 117753, 'ra_deg': 340.54377179750253, 'dec_deg': 19.996990330798187, 'name': '2004ef_DES_z_global', 'orientation_deg': -21.278787865892244, 'semi_major_axis_arcsec': 35.79983094996157, 'semi_minor_axis_arcsec': 33.59238007047011, 'type': 'global', 'software_version': None, 'cutout': 37693, 'transient': 2624}
# global_aperture_DES_z_filter  : {'id': 23, 'name': 'DES_z', 'kcorrect_name': 'decam_z', 'sedpy_id': 'des_z', 'hips_id': 'CDS/P/DES-DR1/z', 'vosa_id': 'CTIO/DECam.z', 'image_download_method': 'custom', 'pixel_size_arcsec': 0.2637, 'image_fwhm_arcsec': 0.93, 'wavelength_eff_angstrom': 9157.9, 'wavelength_min_angstrom': 8341.2, 'wavelength_max_angstrom': 10074.26, 'vega_zero_point_jansky': 2247.33, 'magnitude_zero_point': 22.5, 'ab_offset': 0.0, 'magnitude_zero_point_keyword': None, 'image_pixel_units': 'counts/sec', 'survey': 6}
# global_aperture_DES_z_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_DES_Y_id      : None
# global_aperture_DES_Y_flux    : None
# global_aperture_DES_Y_flux_error: None
# global_aperture_DES_Y_magnitude: None
# global_aperture_DES_Y_magnitude_error: None
# global_aperture_DES_Y_is_validated: None
# global_aperture_DES_Y_software_version: None
# global_aperture_DES_Y_aperture: None
# global_aperture_DES_Y_filter  : None
# global_aperture_DES_Y_transient: None
# local_aperture_host_id        : 9444
# local_aperture_host_log_mass_16: 9.09200203997593
# local_aperture_host_log_mass_50: 9.222703316866134
# local_aperture_host_log_mass_84: 9.349392284205495
# local_aperture_host_mass_surviving_ratio: 0.5738302241278326
# local_aperture_host_log_sfr_16: -1.7070175640929695
# local_aperture_host_log_sfr_50: -1.142086258466557
# local_aperture_host_log_sfr_84: -0.6200952329304482
# local_aperture_host_log_ssfr_16: -10.97622820315813
# local_aperture_host_log_ssfr_50: -10.36921739121696
# local_aperture_host_log_ssfr_84: -9.82332607733897
# local_aperture_host_log_age_16: 6.390808167015088
# local_aperture_host_log_age_50: 7.884289152714538
# local_aperture_host_log_age_84: 10.741410509101058
# local_aperture_host_logzsol_16: -1.620763925433159
# local_aperture_host_logzsol_50: -1.0161800384521484
# local_aperture_host_logzsol_84: -0.5447026824951172
# local_aperture_host_dust2_16  : 0.3980902791917324
# local_aperture_host_dust2_50  : 0.8026975691318512
# local_aperture_host_dust2_84  : 1.1316379868984223
# local_aperture_host_dust_index_16: -0.6517444036006927
# local_aperture_host_dust_index_50: -0.28947779536247253
# local_aperture_host_dust_index_84: 0.0294486815929413
# local_aperture_host_dust1_fraction_16: 0.6205970422625542
# local_aperture_host_dust1_fraction_50: 0.9563248455524445
# local_aperture_host_dust1_fraction_84: 1.3156642628908157
# local_aperture_host_log_fagn_16: -3.879607271909714
# local_aperture_host_log_fagn_50: -1.878575623035431
# local_aperture_host_log_fagn_84: -0.5210019354224203
# local_aperture_host_log_agn_tau_16: 0.8845659334659577
# local_aperture_host_log_agn_tau_50: 1.2774408459663391
# local_aperture_host_log_agn_tau_84: 1.8526051692962646
# local_aperture_host_gas_logz_16: -1.6978786479234695
# local_aperture_host_gas_logz_50: -0.4142337888479233
# local_aperture_host_gas_logz_84: 0.25848901864886287
# local_aperture_host_duste_qpah_16: 0.6094904358386993
# local_aperture_host_duste_qpah_50: 1.979916751384735
# local_aperture_host_duste_qpah_84: 4.26424793100357
# local_aperture_host_duste_umin_16: 2.7984518954753876
# local_aperture_host_duste_umin_50: 7.9286792278289795
# local_aperture_host_duste_umin_84: 15.04220242023468
# local_aperture_host_log_duste_gamma_16: -3.415066071510315
# local_aperture_host_log_duste_gamma_50: -2.4630820751190186
# local_aperture_host_log_duste_gamma_84: -1.2517602808475494
# local_aperture_host_chains_file: /cutouts/data/sed_output/2004ef/2004ef_local_chain.npz
# local_aperture_host_percentiles_file: /cutouts/data/sed_output/2004ef/2004ef_local_perc.npz
# local_aperture_host_model_file: /cutouts/data/sed_output/2004ef/2004ef_local_modeldata.npz
# local_aperture_host_software_version: None
# local_aperture_host_transient : {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# local_aperture_host_aperture  : {'id': 115459, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef_local', 'orientation_deg': 0.0, 'semi_major_axis_arcsec': 3.228509892904693, 'semi_minor_axis_arcsec': 3.228509892904693, 'type': 'local', 'software_version': None, 'cutout': None, 'transient': 2624}
# global_aperture_host_log_agn_tau_50: 1.399170458316803
# global_aperture_host_log_agn_tau_84: 1.8654191232919692
# global_aperture_host_gas_logz_16: -1.6245295207500459
# global_aperture_host_gas_logz_50: -0.8493591248989105
# global_aperture_host_gas_logz_84: -0.06687931686639777
# global_aperture_host_duste_qpah_16: 0.3251541330516338
# global_aperture_host_duste_qpah_50: 1.3721917271614075
# global_aperture_host_duste_qpah_84: 3.8743522286415106
# global_aperture_host_duste_umin_16: 2.2441875221729277
# global_aperture_host_duste_umin_50: 7.105465412139893
# global_aperture_host_duste_umin_84: 14.224328713417053
# global_aperture_host_log_duste_gamma_16: -3.629174196243286
# global_aperture_host_log_duste_gamma_50: -2.2813538312911987
# global_aperture_host_log_duste_gamma_84: -1.1726619919538497
# global_aperture_host_chains_file: /cutouts/data/sed_output/2004ef/2004ef_global_chain.npz
# global_aperture_host_percentiles_file: /cutouts/data/sed_output/2004ef/2004ef_global_perc.npz
# global_aperture_host_model_file: /cutouts/data/sed_output/2004ef/2004ef_global_modeldata.npz
# global_aperture_host_software_version: None
# global_aperture_host_transient: {'id': 2624, 'ra_deg': 340.54174583333327, 'dec_deg': 19.994555555555557, 'name': '2004ef', 'tns_id': 0, 'tns_prefix': '', 'public_timestamp': None, 'tasks_initialized': 'True', 'redshift': 0.03002, 'spectroscopic_class': 'SN Ia\r', 'photometric_class': None, 'milkyway_dust_reddening': 0.047228389531373975, 'processing_status': 'completed', 'image_trim_status': 'processed', 'progress': 100, 'software_version': '1.2.0', 'host': 12156, 'added_by': 1}
# global_aperture_host_aperture : {'id': 117687, 'ra_deg': 340.54377179750253, 'dec_deg': 19.996990330798187, 'name': '2004ef_2MASS_H_global', 'orientation_deg': -21.278787865892244, 'semi_major_axis_arcsec': 37.66983094996157, 'semi_minor_axis_arcsec': 35.46238007047011, 'type': 'global', 'software_version': None, 'cutout': 37423, 'transient': 2624}
# global_aperture_host_logsfh   : [{'id': 74553, 'logsfr_16': -1.8361580024815327, 'logsfr_50': -0.36519451444254475, 'logsfr_84': 0.7122358971271561, 'logsfr_tmin': 1e-09, 'logsfr_tmax': 0.0299999133271615, 'software_version': None, 'transient': 2624, 'aperture': 117687}, {'id': 74554, 'logsfr_16': -1.7194702676007732, 'logsfr_50': -0.1901447795518816, 'logsfr_84': 1.039044788347175, 'logsfr_tmin': 0.0299999133271615, 'logsfr_tmax': 0.1, 'software_version': None, 'transient': 2624, 'aperture': 117687}, {'id': 74555, 'logsfr_16': -2.0329807012604117, 'logsfr_50': -0.337110464397507, 'logsfr_84': 0.8000156205818073, 'logsfr_tmin': 0.1, 'logsfr_tmax': 0.33102456439425765, 'software_version': None, 'transient': 2624, 'aperture': 117687}, {'id': 74556, 'logsfr_16': -1.974339695085442, 'logsfr_50': -0.15947317698973162, 'logsfr_84': 0.6715296417713986, 'logsfr_tmin': 0.33102456439425765, 'logsfr_tmax': 1.0957726223240805, 'software_version': None, 'transient': 2624, 'aperture': 117687}, {'id': 74557, 'logsfr_16': -1.0185966921271397, 'logsfr_50': 0.5374721183298602, 'logsfr_84': 1.1251484640350395, 'logsfr_tmin': 1.0957726223240805, 'logsfr_tmax': 3.627276549799836, 'software_version': None, 'transient': 2624, 'aperture': 117687}, {'id': 74558, 'logsfr_16': -0.017064586173281233, 'logsfr_50': 0.9737118665156499, 'logsfr_84': 1.2077615788864722, 'logsfr_tmin': 3.627276549799836, 'logsfr_tmax': 12.007176398349966, 'software_version': None, 'transient': 2624, 'aperture': 117687}, {'id': 74559, 'logsfr_16': 0.34698933836645957, 'logsfr_50': 1.2076745796234853, 'logsfr_84': 2.100026990980707, 'logsfr_tmin': 12.007176398349966, 'logsfr_tmax': 13.341307109277729, 'software_version': None, 'transient': 2624, 'aperture': 117687}]

# %% [markdown]
# ### DES5YR Host Galaxy Association ###
#
# The pirmary challenge of this data set is that the Hubble Diagram data found at the following link:

# %%
# Load your CSV 
csv_path = "des_sample_SNIa.csv"
df = pd.read_csv(csv_path)

# Collect BLAST info
blast_rows = []
missing_from_blast = []

for sn in df["CID"]:   # or df["SNID"]
    row, missing = get_blast_info(sn)
    blast_rows.append(row)
    if missing:   # missing is sn_name or None
        missing_from_blast.append(missing)

# Merge results back into DataFrame
blast_df = pd.DataFrame(blast_rows)
df = pd.concat([df, blast_df], axis=1)

# Save to new file
df.to_csv("explore_webapi_with_blast.csv", index=False)

print("Failed lookups:", missing_from_blast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load your CSV
#       2 csv_path = "des_sample_SNIa.csv"
# ----> 3 df = pd.read_csv(csv_path)
#       5 # Collect BLAST info
#       6 blast_rows = []
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Taking the Data that We Need
#
# For our purposes, we are interested in a specific subset of BLAST-computed full payload parameters.
#
#
# ### Host SED Fitting Results
#
# - An **SED** is the distribution of a galaxy’s brightness as a function of wavelength (essentially, how much light it emits in each filter).
# - Different stellar populations, star formation histories, and dust contents shape the SED differently.
# - By comparing the observed photometry (points in different filters) to a grid or model of theoretical SEDs, we can infer underlying galaxy properties.
#
# - BLAST uses the **Prospector** Bayesian inference framework, accelerated with **simulation-based inference**.
# - Observed photometry (from surveys like SDSS, PS1, 2MASS, WISE, etc.) is fed into Prospector models.
# - A **Bayesian posterior distribution** is generated for each physical parameter.
# - The API exposes **summary statistics** from those posteriors: the 16th, 50th (median), and 84th percentiles.
#
# - `<aperture_type>`:
#   - **`local`** — properties measured within ~2 kpc of the SN location.
#   - **`global`** — properties measured for the entire host galaxy.
#
# - `<parameter>`:
#   - **`log_mass`** — log₁₀ of the surviving host stellar mass [M☉]
#   - **`log_sfr`** — log₁₀ of the host star formation rate [M☉ yr⁻¹]
#   - **`log_ssfr`** — log₁₀ of the host specific star formation rate [yr⁻¹]
#   - **`log_age`** — log₁₀ of the mass-weighted stellar age [yr]
#
# NOTE: BLAST provides the 16th, 50th, and 84th percentiles of the posterior for each parameter.
#
#
# ### Host Photometry
#
# We also want the raw host photometry (magnitudes, fluxes, errors) for both local and global apertures,
# as this can be used for further derived quantities (e.g., colors, surface densities). This is just in case we have the time for this.
#
# ### Supernova (SN Ia) Information
#
# We would also like to store the following SN level data:
#
# - `sn_name`
# - `sn_ra_deg` — SN RA in decimal degrees
# - `sn_dec_deg` — SN Dec in decimal degrees
# - `sn_redshift` — SN redshift
# - `sn_spectroscopic_class`
# - `sn_photometric_class`
# - `sn_processing_status` — BLAST processing state for this transient

# %%
# Builds the full science payload URL for the given transient name (e.g., 2004ef).
# Opens the URL, reads the response, and parses it from JSON text into a Python dict.

## note: {} inside an f-string ends up being replaced with the value of the variable. 
## the physical charcters of "{" or "}" are not inlcuded. 
def fetch_payload(name: str):
    url = f"https://blast.ncsa.illinois.edu/api/transient/get/{name}?format=json"
    with urlopen(url) as r:
        return json.loads(r.read())


## MAYBE THIS IS UNECESSARY JUST RETURN THE TRANSIENT SPECTROSCOPIC CLASS OR THE TRANSEINT PHOTOMETRICK CASS

## RED FLAG UNNECESSARY AS ALL THE SNIA that we are passing through are already TYPE Ia. Now weathe they are photometrically or spectroscopically confirmed is another issue alltogether.

def is_snia(payload: dict) -> bool:
    """Return True if BLAST thinks this is (probably) a Type Ia."""
    sc = (payload.get("transient_spectroscopic_class") or "").strip().lower()
    pc = (payload.get("transient_photometric_class") or "").strip().lower()
    return ("ia" in sc) or ("ia" in pc)

def _get(payload, key, default=None):
    return payload.get(key, default)

## DEFINES THE PARAMETERS YOU WANT FROM THE PAYLOAD ##
## payload is the input variable and its type is a dictionary. 
def extract_catalog_row(payload: dict):

    ## Create a dictionary called "row". 
    ## values like "transient_name" will be assigned to the left most
    ## keys like "transient_name" on the very left hand side. 
    row = {
        # SN id / position / z / classes
        "transient_name": _get(payload, "transient_name"),
        "transient_spectroscopic_class": (payload.get("transient_spectroscopic_class") or "").strip(),
        "transient_photometric_class": (payload.get("transient_photometric_class") or "").strip(),
        "transient_ra_deg": _get(payload, "transient_ra_deg"),
        "transient_dec_deg": _get(payload, "transient_dec_deg"),
        "transient_redshift": _get(payload, "transient_redshift"),
        "transient_spectroscopic_class": (payload.get("transient_spectroscopic_class") or "").strip(),
        "transient_photometric_class": (payload.get("transient_photometric_class") or "").strip(),
        "transient_processing_status": _get(payload, "transient_processing_status"),

        # Host basics
        "host_name": _get(payload, "host_name"),
        "host_ra_deg": _get(payload, "host_ra_deg"),
        "host_dec_deg": _get(payload, "host_dec_deg"),
        "host_redshift": _get(payload, "host_redshift"),
        "host_EBV_MW": _get(payload, "host_milkyway_dust_reddening"),
    }

    # SED medians (p50) for both local & global ( p16/p84 are not included)
    params = ["log_mass", "log_sfr", "log_ssfr", "log_age"]
    for scope in ("local", "global"):
        for p in params:
            key = f"{scope}_aperture_host_{p}_50"
            row[f"{scope}_{p}_50"] = _get(payload, key)
        # optional quality-ish extra
        row[f"{scope}_mass_surviving_ratio"] = _get(payload, f"{scope}_aperture_host_mass_surviving_ratio")

    return row

_PHOT_RE = re.compile(
    r'^(?P<scope>local|global)_aperture_(?P<survey>[A-Za-z0-9]+)_(?P<band>[A-Za-z0-9]+)_(?P<quantity>magnitude|magnitude_error|flux|flux_error|is_validated)$',
    re.I
)

def extract_photometry_rows(payload: dict):
    """Return long-form rows for photometry with mag/flux + errors."""
    rows = defaultdict(dict)
    base_id = {
        "sn_name": _get(payload, "transient_name"),
        "host_name": _get(payload, "host_name"),
    }

    for k, v in payload.items():
        m = _PHOT_RE.match(k)
        if not m:
            continue
        scope, survey, band, quantity = m.group("scope","survey","band","quantity")
        idx = (scope.lower(), survey, band)
        if "scope" not in rows[idx]:
            rows[idx].update(base_id)
            rows[idx]["scope"] = scope.lower()
            rows[idx]["survey"] = survey
            rows[idx]["band"] = band
        rows[idx][quantity] = v

    # normalize booleans, missing values
    out = []
    for r in rows.values():
        r.setdefault("magnitude", None)
        r.setdefault("magnitude_error", None)
        r.setdefault("flux", None)
        r.setdefault("flux_error", None)
        # convert is_validated to bool if present
        if "is_validated" in r and isinstance(r["is_validated"], str):
            r["is_validated"] = r["is_validated"].lower() == "true"
        out.append(r)
    return out

# --------------------------- main routine ---------------------------

def build_blash_catalog(sn_names, require_snia=True,
                        catalog_csv="blast_hosts_catalog.csv",
                        photometry_csv="blast_hosts_photometry.csv"):
    cat_rows, phot_rows = [], []

    for name in sn_names:
        try:
            payload = fetch_payload(name)
        except Exception as e:
            print(f"[WARN] {name}: fetch failed: {e}")
            continue

        if require_snia and not is_snia(payload):
            print(f"[SKIP] {name}: not Ia by BLAST labels")
            continue

        cat_rows.append(extract_catalog_row(payload))
        phot_rows.extend(extract_photometry_rows(payload))

    cat_df = pd.DataFrame(cat_rows)
    phot_df = pd.DataFrame(phot_rows)

    # Save
    if not cat_df.empty:
        cat_df.to_csv(catalog_csv, index=False)
        print(f"[OK] wrote {catalog_csv} ({len(cat_df)} rows)")
    else:
        print("[INFO] catalog is empty")

    if not phot_df.empty:
        phot_df.sort_values(["sn_name","scope","survey","band"]).to_csv(photometry_csv, index=False)
        print(f"[OK] wrote {photometry_csv} ({len(phot_df)} rows)")
    else:
        print("[INFO] photometry is empty")

    return cat_df, phot_df

# --------------------------- example --------------------------- #

if __name__ == "__main__":
    # Replace with your list
    targets = ["2004ef", "2018gv", "2011fe", "2014J"]
    catalog, phot = build_blash_catalog(targets)
# Out:
# [OK] wrote blast_hosts_catalog.csv (4 rows)
# [OK] wrote blast_hosts_photometry.csv (192 rows)

# %% [markdown]
# ## Output Analysis
#
# When we perform a **full payload** BLAST API query (`/api/transient/get/<name>?format=json`),
# the returned JSON is large and contains a wide range of information.
#
# For our purposes, we are interested in a **specific subset** of BLAST-computed parameters.
#
#
# ### SED Fitting Results
#
# **API reference:** `/api/sedfittingresult/`
#
# - `<aperture_type>` can be either:
#   - **`local`** — properties measured within ~2 kpc of the SN location.
#   - **`global`** — properties measured for the entire host galaxy.
#
# - `<parameter>` can be one of:
#   - **`log_mass`** — log₁₀ of the surviving host stellar mass [M☉]
#   - **`log_sfr`** — log₁₀ of the host star formation rate [M☉ yr⁻¹]
#   - **`log_ssfr`** — log₁₀ of the host specific star formation rate [yr⁻¹]
#   - **`log_age`** — log₁₀ of the mass-weighted stellar age [yr]
#
# BLAST typically provides the **16th, 50th, and 84th percentiles** of the posterior for each parameter.
#
#
# ### Host Photometry
#
# We also want the **host photometry** (magnitudes, fluxes, errors) for both local and global apertures,
# as this can be used for further derived quantities (e.g., colors, surface densities).
#
#
# ### Supernova (SN Ia) Information
#
# If available in the BLAST payload, we also store the following SN-level metadata:
#
# - `sn_name`
# - `sn_ra_deg` — SN RA in decimal degrees
# - `sn_dec_deg` — SN Dec in decimal degrees
# - `sn_redshift` — SN redshift
# - `sn_spectroscopic_class`
# - `sn_photometric_class`
# - `sn_processing_status` — BLAST processing state for this transient

# %%
# Load the CSV
df = pd.read_csv("blast_hosts_catalog.csv")

# Show the column names
print("Number of columns:", len(df.columns))
print("\nColumn names:")
for col in df.columns:
    print(f"- {col}")
# Out:
# Number of columns: 22
#
# Column names:
# - sn_name
# - sn_ra_deg
# - sn_dec_deg
# - sn_redshift
# - sn_spectroscopic_class
# - sn_photometric_class
# - sn_processing_status
# - host_name
# - host_ra_deg
# - host_dec_deg
# - host_redshift
# - host_EBV_MW
# - local_log_mass_50
# - local_log_sfr_50
# - local_log_ssfr_50
# - local_log_age_50
# - local_mass_surviving_ratio
# - global_log_mass_50
# - global_log_sfr_50
# - global_log_ssfr_50
# - global_log_age_50
# - global_mass_surviving_ratio

# %% [markdown]
# # What BLAST Gives You for **Host Galaxies** (useful fields to pull)
#
# BLAST pre-computes host properties by fitting multi-band photometry with **Prospector** (Bayesian SED inference, accelerated via simulation-based inference). You get values for both **global** (whole galaxy) and **local** (≈2 kpc around the SN) apertures.
#
# The complete list of the data being stored can be found at the following
#
# ## 1) Host identification & basics
# - `host_name` — host identifier (may be internal)
# - `host_ra_deg`, `host_dec_deg` — host coordinates (deg)
# - `host_redshift` — spectroscopic/assigned host redshift (dimensionless)
# - `host_milkyway_dust_reddening` — Galactic E(B−V) toward the host (mag)
#
# > Also useful for context:
# > - `sn_name`, `sn_ra_deg`, `sn_dec_deg`, `sn_redshift`
# > - `sn_spectroscopic_class`, `sn_photometric_class`
#
# ## 3) SED-fit **derived** physical properties (per scope)
# BLAST exposes percentile summaries (typically 16/50/84). Field-name pattern:
# `<scope>_aperture_host_<parameter>_<percentile>`
#
# Core parameters:
# - `..._log_mass_{16,50,84}` — log10 stellar mass (M☉)
# - `..._log_sfr_{16,50,84}` — log10 SFR (M☉/yr)
# - `..._log_ssfr_{16,50,84}` — log10 sSFR (yr⁻¹)
# - `..._log_age_{16,50,84}` — log10 mass-weighted stellar age (yr)
# - `..._mass_surviving_ratio` — surviving / formed stellar mass (dimensionless)
#
# > Notes
# > - The “50” (median) is what your current CSV keeps (e.g., `local_log_mass_50`).
# > - Keep 16/84 as uncertainties: e.g., `log_mass_err_minus = 50−16`, `log_mass_err_plus = 84−50`.
# > - Some payloads may include additional SED parameters (e.g., `log_tau`) depending on the BLAST run.
#
# ## 4) **Photometry** used by the SED fits (per scope, survey, and band)
# Field-name pattern:
# `<scope>_aperture_<SURVEY>_<BAND>_{magnitude,magnitude_error,flux,flux_error,is_validated}`
#
# Examples (not exhaustive):
# - `local_aperture_SDSS_g_magnitude`, `local_aperture_SDSS_g_magnitude_error`
# - `global_aperture_PS1_i_flux`, `global_aperture_PS1_i_flux_error`
# - `..._is_validated` (boolean-ish flag)
#
# > Use these if you want to recompute colors, surface densities, or test alternative SED assumptions.
#
# ---
#
# ## Quick reference: what to keep in a tidy “host catalog” table
# For each SN (row), include at least:
#
# **Identification**
# - `sn_name`, `host_name`, `host_redshift`, `host_ra_deg`, `host_dec_deg`, `host_milkyway_dust_reddening`
#
# **Global (whole galaxy)**
# - `global_log_mass_50`, `global_log_mass_16`, `global_log_mass_84`
# - `global_log_sfr_50`,  `global_log_sfr_16`,  `global_log_sfr_84`
# - `global_log_ssfr_50`, `global_log_ssfr_16`, `global_log_ssfr_84`
# - `global_log_age_50`,  `global_log_age_16`,  `global_log_age_84`
# - `global_mass_surviving_ratio`
#
# **Local (≈2 kpc)**
# - `local_log_mass_50`, `local_log_mass_16`, `local_log_mass_84`
# - `local_log_sfr_50`,  `local_log_sfr_16`,  `local_log_sfr_84`
# - `local_log_ssfr_50`, `local_log_ssfr_16`, `local_log_ssfr_84`
# - `local_log_age_50`,  `local_log_age_16`,  `local_log_age_84`
# - `local_mass_surviving_ratio`
#
# ---
#
# ## Optional “you compute it” derived quantities (from the above)
# - **Uncertainty widths**: e.g., `σ⁺ = p84 − p50`, `σ⁻ = p50 − p16`
# - **Surface stellar mass density** (Σ\*) if aperture areas are known
# - **Colors** from photometry (e.g., `g−r`, `r−i`) for sanity checks
# - **Δ(local−global)** contrasts (e.g., Δlog sSFR) for environment studies
#
# ---
#
# ### Units & conventions
# - Angles in **degrees**
# - Redshifts dimensionless
# - E(B−V) in **magnitudes**
# - `log_mass` in **log10(M☉)**
# - `log_sfr` in **log10(M☉/yr)**
# - `log_ssfr` in **log10(yr⁻¹)**
# - `log_age` in **log10(yr)**
# - Percentiles: `{16,50,84}` ≈ (−1σ, median, +1σ) if posteriors are ~Gaussian

# %%
from urllib.request import urlopen
import json

def get_ra_from_name(sn_name: str) -> float:
    """
    Fetch BLAST payload for a given SN name and return its RA in degrees.
    """
    url = f"https://blast.ncsa.illinois.edu/api/transient/get/{sn_name}?format=json"
    with urlopen(url) as r:
        payload = json.loads(r.read())
    return payload.get("transient_ra_deg")

# Example
print(get_ra_from_name("2004ef"))
# Out:
# 340.54174583333327

# %%
from urllib.request import urlopen
import json
import pandas as pd

# Pick one SN
sn_name = "2004ef"

# Fetch payload from BLAST
url = f"https://blast.ncsa.illinois.edu/api/transient/get/{sn_name}?format=json"
with urlopen(url) as r:
    payload = json.loads(r.read())

# Grab just the RA
ra = payload.get("transient_ra_deg")

# Put into a DataFrame
df = pd.DataFrame([{"sn_name": sn_name, "ra_deg": ra}])

# Save to CSV
df.to_csv("single_snia.csv", index=False)

print(df)
# Out:
#   sn_name      ra_deg
# 0  2004ef  340.541746

# %%
from urllib.request import urlopen
import json
import pandas as pd

# Pick one SN
sn_name = "2004ef"

# Fetch payload from BLAST
url = f"https://blast.ncsa.illinois.edu/api/transient/get/{sn_name}?format=json"
with urlopen(url) as r:
    payload = json.loads(r.read())

# Collect all the desired fields
row = {
    "transient_name": payload.get("transient_name"),
    "transient_spectroscopic_class": (payload.get("transient_spectroscopic_class") or "").strip(),
    "transient_photometric_class": (payload.get("transient_photometric_class") or "").strip(),
    "transient_ra_deg": payload.get("transient_ra_deg"),
    "transient_dec_deg": payload.get("transient_dec_deg"),
    "transient_redshift": payload.get("transient_redshift"),
    "transient_processing_status": payload.get("transient_processing_status"),

    "host_name": payload.get("host_name"),
    "host_ra_deg": payload.get("host_ra_deg"),
    "host_dec_deg": payload.get("host_dec_deg"),
    "host_redshift": payload.get("host_redshift"),
    "host_EBV_MW": payload.get("host_milkyway_dust_reddening"),

    # Local SED
    "local_log_mass_50": payload.get("local_aperture_host_log_mass_50"),
    "local_log_sfr_50": payload.get("local_aperture_host_log_sfr_50"),
    "local_log_ssfr_50": payload.get("local_aperture_host_log_ssfr_50"),
    "local_log_age_50": payload.get("local_aperture_host_log_age_50"),
    "local_mass_surviving_ratio": payload.get("local_aperture_host_mass_surviving_ratio"),

    # Global SED
    "global_log_mass_50": payload.get("global_aperture_host_log_mass_50"),
    "global_log_sfr_50": payload.get("global_aperture_host_log_sfr_50"),
    "global_log_ssfr_50": payload.get("global_aperture_host_log_ssfr_50"),
    "global_log_age_50": payload.get("global_aperture_host_log_age_50"),
    "global_mass_surviving_ratio": payload.get("global_aperture_host_mass_surviving_ratio"),
}

# Put into a DataFrame
df = pd.DataFrame([row])

# Save to CSV
df.to_csv("single_snia_full.csv", index=False)

print(df)
# Out:
#   transient_name transient_spectroscopic_class transient_photometric_class  \
# 0         2004ef                         SN Ia
#
#    transient_ra_deg  transient_dec_deg  transient_redshift  \
# 0        340.541746          19.994556             0.03002
#
#   transient_processing_status host_name  host_ra_deg  host_dec_deg  ...  \
# 0                        None    2004ef   340.543859     19.996943  ...
#
#    local_log_mass_50  local_log_sfr_50  local_log_ssfr_50  local_log_age_50  \
# 0           9.222703         -1.142086         -10.369217          7.884289
#
#    local_mass_surviving_ratio  global_log_mass_50  global_log_sfr_50  \
# 0                     0.57383           10.949363          -0.096142
#
#    global_log_ssfr_50  global_log_age_50  global_mass_surviving_ratio
# 0          -11.008361           8.004165                      0.58122
#
# [1 rows x 22 columns]

# %% [markdown]
# ### DES ###

# %%
# Load your CSV
csv_path = "des_smaple_SNIa.csv"
df = pd.read_csv(csv_path)

missing_from_blast = []


# Make a function to fetch BLAST info for one SN
def get_blast_info(sn_name):
    url = f"https://blast.ncsa.illinois.edu/api/transient/get/{sn_name}?format=json"
    try:
        with urlopen(url) as r:
            payload = json.loads(r.read())
    except Exception as e:
        print(f"Error fetching {sn_name}: {e}")
        missing_from_blast.append(sn_name)   # keep track of failures
        return {}

    row = {
        "blast_transient_spectroscopic_class": (payload.get("transient_spectroscopic_class") or "").strip(),
        "blast_transient_photometric_class": (payload.get("transient_photometric_class") or "").strip(),
        
        "blast_host_name": payload.get("host_name"),
        "blast_host_ra_deg": payload.get("host_ra_deg"),
        "blast_host_dec_deg": payload.get("host_dec_deg"),
        "blast_host_redshift": payload.get("host_redshift"),
        "blast_host_EBV_MW": payload.get("host_milkyway_dust_reddening"),

        # Local SED
        "blast_local_log_mass_50": payload.get("local_aperture_host_log_mass_50"),
        "blast_local_log_sfr_50": payload.get("local_aperture_host_log_sfr_50"),
        "blast_local_log_ssfr_50": payload.get("local_aperture_host_log_ssfr_50"),
        "blast_local_log_age_50": payload.get("local_aperture_host_log_age_50"),
        "blast_local_mass_surviving_ratio": payload.get("local_aperture_host_mass_surviving_ratio"),

        # Global SED
        "blast_global_log_mass_50": payload.get("global_aperture_host_log_mass_50"),
        "blast_global_log_sfr_50": payload.get("global_aperture_host_log_sfr_50"),
        "blast_global_log_ssfr_50": payload.get("global_aperture_host_log_ssfr_50"),
        "blast_global_log_age_50": payload.get("global_aperture_host_log_age_50"),
        "blast_global_mass_surviving_ratio": payload.get("global_aperture_host_mass_surviving_ratio"),
    }
    return row

# Apply to each SN in your CSV (assuming column is "CID" or "SNID")
blast_rows = []
for sn in df["CID"]:   # change to df["SNID"] if that's the column name
    blast_rows.append(get_blast_info(sn))

# Merge the results back into your DataFrame
blast_df = pd.DataFrame(blast_rows)
df = pd.concat([df, blast_df], axis=1)

# Save to new file
df.to_csv("explore_webapi_with_blast.csv", index=False)
print(missing_from_blast)
# Out:
# Error fetching 2001ah: HTTP Error 404: Not Found
# Error fetching 2001ay: HTTP Error 404: Not Found
# Error fetching 2001eh: HTTP Error 404: Not Found
# Error fetching 2002he: HTTP Error 404: Not Found
# Error fetching 2002hu: HTTP Error 404: Not Found
# Error fetching 2003fa: HTTP Error 404: Not Found
# Error fetching 2003iv: HTTP Error 404: Not Found
# Error fetching 2005ms: HTTP Error 404: Not Found
# Error fetching 2006S: HTTP Error 404: Not Found
# Error fetching 2006az: HTTP Error 404: Not Found
# Error fetching 2006cf: HTTP Error 404: Not Found
# Error fetching 2006oa: HTTP Error 404: Not Found
# Error fetching 2006on: HTTP Error 404: Not Found
# Error fetching 2006qo: HTTP Error 404: Not Found
# Error fetching 2007R: HTTP Error 404: Not Found
# Error fetching 2007sw: HTTP Error 404: Not Found
# Error fetching 2008050: HTTP Error 404: Not Found
# Error fetching 2008051: HTTP Error 404: Not Found
# Error fetching 2010dt: HTTP Error 404: Not Found
# Error fetching AT2016ews: HTTP Error 404: Not Found
# Error fetching AT2017po: HTTP Error 404: Not Found
# Error fetching ATLAS17ajn: HTTP Error 404: Not Found
# Error fetching CSS160129: HTTP Error 404: Not Found
# Error fetching PS15asb: HTTP Error 404: Not Found
# Error fetching PS15brr: HTTP Error 404: Not Found
# Error fetching PS15bwh: HTTP Error 404: Not Found
# Error fetching PS15cwx: HTTP Error 404: Not Found
# Error fetching PS16ayd: HTTP Error 404: Not Found
# Error fetching PS16cqa: HTTP Error 404: Not Found
# Error fetching PS16em: HTTP Error 404: Not Found
# Error fetching SN2016aqb: HTTP Error 404: Not Found
# Error fetching SN2016glp: HTTP Error 404: Not Found
# Error fetching SN2016hhv: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# ['2001ah', '2001ay', '2001eh', '2002he', '2002hu', '2003fa', '2003iv', '2005ms', '2006S', '2006az', '2006cf', '2006oa', '2006on', '2006qo', '2007R', '2007sw', '2008050', '2008051', '2010dt', 'AT2016ews', 'AT2017po', 'ATLAS17ajn', 'CSS160129', 'PS15asb', 'PS15brr', 'PS15bwh', 'PS15cwx', 'PS16ayd', 'PS16cqa', 'PS16em', 'SN2016aqb', 'SN2016glp', 'SN2016hhv', nan]

# %%
import pandas as pd

csv_in  = "explore_webapi_with_blast.csv"
csv_out = "explore_webapi_with_blast_only.csv"
csv_missing = "missing_from_blast.csv"

# Load
df = pd.read_csv(csv_in)

# All BLAST columns (those we added with the 'blast_' prefix)
blast_cols = [c for c in df.columns if c.startswith("blast_")]

# Mark rows that have at least ONE non-null BLAST value
has_blast = df[blast_cols].notna().any(axis=1)

# Keep only rows with BLAST info
kept = df[has_blast].copy()

# Rows removed = missing from BLAST entirely
missing = df[~has_blast].copy()

# (Optional) pick a likely name/ID column to show in the missing file
name_col = next((c for c in ["CID", "SNID", "transient_name"] if c in df.columns), None)
if name_col:
    missing = missing[[name_col] + blast_cols]  # show identifier + the empty blast columns

# Save results
kept.to_csv(csv_out, index=False)
missing.to_csv(csv_missing, index=False)

print(f"Kept {len(kept)} rows with BLAST data → {csv_out}")
print(f"Removed {len(missing)} rows missing BLAST data → {csv_missing}")
# Out:
# Kept 161 rows with BLAST data → explore_webapi_with_blast_only.csv
# Removed 34 rows missing BLAST data → missing_from_blast.csv

# %% [markdown]
# ## SHOES ###

# %%
# Load your CSV
csv_path = "Pantheon+SH0ES.csv"
df = pd.read_csv(csv_path)

missing_from_blast = []


# Make a function to fetch BLAST info for one SN
def get_blast_info(sn_name):
    url = f"https://blast.ncsa.illinois.edu/api/transient/get/{sn_name}?format=json"
    try:
        with urlopen(url) as r:
            payload = json.loads(r.read())
    except Exception as e:
        print(f"Error fetching {sn_name}: {e}")
        missing_from_blast.append(sn_name)   # keep track of failures
        return {}

    row = {
        "blast_transient_spectroscopic_class": (payload.get("transient_spectroscopic_class") or "").strip(),
        "blast_transient_photometric_class": (payload.get("transient_photometric_class") or "").strip(),
        
        "blast_host_name": payload.get("host_name"),
        "blast_host_ra_deg": payload.get("host_ra_deg"),
        "blast_host_dec_deg": payload.get("host_dec_deg"),
        "blast_host_redshift": payload.get("host_redshift"),
        "blast_host_EBV_MW": payload.get("host_milkyway_dust_reddening"),

        # Local SED
        "blast_local_log_mass_50": payload.get("local_aperture_host_log_mass_50"),
        "blast_local_log_sfr_50": payload.get("local_aperture_host_log_sfr_50"),
        "blast_local_log_ssfr_50": payload.get("local_aperture_host_log_ssfr_50"),
        "blast_local_log_age_50": payload.get("local_aperture_host_log_age_50"),
        "blast_local_mass_surviving_ratio": payload.get("local_aperture_host_mass_surviving_ratio"),

        # Global SED
        "blast_global_log_mass_50": payload.get("global_aperture_host_log_mass_50"),
        "blast_global_log_sfr_50": payload.get("global_aperture_host_log_sfr_50"),
        "blast_global_log_ssfr_50": payload.get("global_aperture_host_log_ssfr_50"),
        "blast_global_log_age_50": payload.get("global_aperture_host_log_age_50"),
        "blast_global_mass_surviving_ratio": payload.get("global_aperture_host_mass_surviving_ratio"),
    }
    return row

# Apply to each SN in your CSV (assuming column is "CID" or "SNID")
blast_rows = []
for sn in df["CID"]:   # change to df["SNID"] if that's the column name
    blast_rows.append(get_blast_info(sn))

# Merge the results back into your DataFrame
blast_df = pd.DataFrame(blast_rows)
df = pd.concat([df, blast_df], axis=1)

# Save to new file
df.to_csv("explore_webapi_with_blast_SHOES_post_additional_analysis.csv", index=False)
print(missing_from_blast)
# Out:
# Error fetching 1994DRichmond: HTTP Error 404: Not Found
# Error fetching 2017cbv: HTTP Error 404: Not Found
# Error fetching 2017cbv: HTTP Error 404: Not Found
# Error fetching 1998aq: HTTP Error 404: Not Found
# Error fetching 1990N: HTTP Error 404: Not Found
# Error fetching 2005df_ANU: HTTP Error 404: Not Found
# Error fetching 1994ae: HTTP Error 404: Not Found
# Error fetching 2015bp: HTTP Error 404: Not Found
# Error fetching 2008Q: HTTP Error 404: Not Found
# Error fetching 2008Q: HTTP Error 404: Not Found
# Error fetching 1996Z: HTTP Error 404: Not Found
# Error fetching 2013gh: HTTP Error 404: Not Found
# Error fetching 2013gh: HTTP Error 404: Not Found
# Error fetching PSNJ0717457: HTTP Error 404: Not Found
# Error fetching 1997bp: HTTP Error 404: Not Found
# Error fetching 1997do: HTTP Error 404: Not Found
# Error fetching 2008fv_comb: HTTP Error 404: Not Found
# Error fetching ASASSN-16jf: HTTP Error 404: Not Found
# Error fetching ASASSN-16dn: HTTP Error 404: Not Found
# Error fetching 2013fa: HTTP Error 404: Not Found
# Error fetching 2011im: HTTP Error 404: Not Found
# Error fetching 2008eo: HTTP Error 404: Not Found
# Error fetching 2007ss: HTTP Error 404: Not Found
# Error fetching 1998V: HTTP Error 404: Not Found
# Error fetching ASASSN-16lc: HTTP Error 404: Not Found
# Error fetching 2004bw: HTTP Error 404: Not Found
# Error fetching SN2016ajf: HTTP Error 404: Not Found
# Error fetching ASASSN-18da: HTTP Error 404: Not Found
# Error fetching ASASSN-18iu: HTTP Error 404: Not Found
# Error fetching 2002cu: HTTP Error 404: Not Found
# Error fetching ASASSN-16bn: HTTP Error 404: Not Found
# Error fetching AT2016bln: HTTP Error 404: Not Found
# Error fetching 370356: HTTP Error 404: Not Found
# Error fetching SNF20071021-000: HTTP Error 404: Not Found
# Error fetching 1998ab: HTTP Error 404: Not Found
# Error fetching ASASSN-16hh: HTTP Error 404: Not Found
# Error fetching ATLAS17ajn: HTTP Error 404: Not Found
# Error fetching ASASSN-16es: HTTP Error 404: Not Found
# Error fetching PS15cwx: HTTP Error 404: Not Found
# Error fetching SNF20080909-030: HTTP Error 404: Not Found
# Error fetching AT2017po: HTTP Error 404: Not Found
# Error fetching 2003kc: HTTP Error 404: Not Found
# Error fetching SN2017ciy: HTTP Error 404: Not Found
# Error fetching 2008051: HTTP Error 404: Not Found
# Error fetching PS16cqa: HTTP Error 404: Not Found
# Error fetching 2008050: HTTP Error 404: Not Found
# Error fetching AT2016ews: HTTP Error 404: Not Found
# Error fetching 1993ag: HTTP Error 404: Not Found
# Error fetching PS15asb: HTTP Error 404: Not Found
15897', '120143', '15648', '14421', '16165', '5350', '15583', '19969', '18604', '14979', '17218', '14451', '17220', '370428', '5635', '6936', '300179', '13045', '1347120', '2372', '1303496', '13254', '14284', '420159', '330023', '350548', '360112', '17215', '370595', '15443', '1339392', '17332', '1580', '1250017', '15453', '17391', '1257695', '17168', '20048', '1296321', '15421', '8213', '15461', '1336453', '6422', '16281', '370563', '15365', '18807', '5994', '12927', '16100', '1273127', '18787', '18749', '440643', '6304', '762', '20687', '2440', '16276', '2246', '20821', '1253920', '14984', '15674', '000236', '15129', '1298893', '1334620', '13070', '18804', '1302058', '15222', '1316431', '13370', '360145', '19658', '18768', '110460', '500504', '560150', '19101', '470232', '370308', '590002', '13152', '19913', '6780', '14212', '15203', '16032', '7243', '15901', '18965', '110033', '17801', '15872', '1327978', '15201', '1283373', '20376', '15467', '200132', '15259', '140152', '16482', '550154', '19149', '460105', '14157', '18940', '1257366', '7847', '17811', '18927', '13305', '8495', '6933', '110567', '1249851', '14019', '1316', '100206', '17435', '7473', '20364', '13641', '1290816', '1304678', '9467', '5533', '1342255', '1302187', '15433', '000220', '18466', '14331', '19230', '7512', '15354', '370098', '480464', '1331123', '13025', '14846', '330083', '1304442', '550096', '1292560', '030066', '13727', '15229', '020096', '19992', '1315192', '1315259', '180561', '13072', '3452', '21033', '000006', '040780', '19008', '360140', '17875', '430004', '1302648', '1275946', '15369', '1292336', '350047', '1336687', '12971', '110536', '1279500', '1319366', '1298281', '19341', '15287', '310574', '13511', '12881', '16350', '1317277', '20768', '17884', '470008', '18486', '510251', '580300', '510550', '460064', '17223', '14481', '20111', '480064', '20088', '13506', '19023', '15466', '3377', '000174', '420407', '20039', '000010', '13835', '15219', '12977', '05D3mq', '1334645', '3451', '420087', '450082', '560152', '15161', '19990', '120585', '3199', '16106', '15868', '520077', '3904 ...

# %%
import pandas as pd

csv_in  = "explore_webapi_with_blast_SHOES_post_additional_analysis.csv"
csv_out = "explore_webapi_with_blast_only_SHOES_post_additional_analysis.csv"
csv_missing = "missing_from_blast_SHOES_post_additional_analysis.csv"

# Load
df = pd.read_csv(csv_in)

# All BLAST columns (those we added with the 'blast_' prefix)
blast_cols = [c for c in df.columns if c.startswith("blast_")]

# Mark rows that have at least ONE non-null BLAST value
has_blast = df[blast_cols].notna().any(axis=1)

# Keep only rows with BLAST info
kept = df[has_blast].copy()

# Rows removed = missing from BLAST entirely
missing = df[~has_blast].copy()

# (Optional) pick a likely name/ID column to show in the missing file
name_col = next((c for c in ["CID", "SNID", "transient_name"] if c in df.columns), None)
if name_col:
    missing = missing[[name_col] + blast_cols]  # show identifier + the empty blast columns

# Save results
kept.to_csv(csv_out, index=False)
missing.to_csv(csv_missing, index=False)

print(f"Kept {len(kept)} rows with BLAST data → {csv_out}")
print(f"Removed {len(missing)} rows missing BLAST data → {csv_missing}")
# Out:
# Kept 692 rows with BLAST data → explore_webapi_with_blast_only_SHOES_post_additional_analysis.csv
# Removed 1009 rows missing BLAST data → missing_from_blast_SHOES_post_additional_analysis.csv

# %%
PANTHEON_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/Pantheon+SH0ES.csv"
BLAST_SHOES_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/explore_webapi_with_blast_only_SHOES.csv"

# Load CSVs
pantheon = pd.read_csv(PANTHEON_CSV)
blast_shoes = pd.read_csv(BLAST_SHOES_CSV)

# Extract redshifts
z_all_pantheon = pd.to_numeric(pantheon["zHEL"], errors="coerce").dropna().to_numpy()
z_blast_subset = pd.to_numeric(blast_shoes["zHEL"], errors="coerce").dropna().to_numpy()

print(f"Counts — Pantheon+SH0ES all: {z_all_pantheon.size}, BLAST subset: {z_blast_subset.size}")

# Shared binning (explicit control here!)
zmin, zmax = min(z_all_pantheon.min(), z_blast_subset.min()), \
             max(z_all_pantheon.max(), z_blast_subset.max())
bins = np.linspace(zmin, zmax, 100)   # adjust number of bins here

# Plot
plt.figure(figsize=(12, 6))
plt.hist(z_all_pantheon, bins=bins, alpha=0.3, label="Pantheon+SH0ES SNe Ia (zHEL)", color="red")
plt.hist(z_blast_subset, bins=bins, alpha=0.8, label="BLAST-covered Pantheon+SH0ES (zHEL)", color="black")

plt.xlabel("Redshift z")
plt.ylabel("Count")
plt.title("Redshift Distributions: Pantheon+SH0ES vs BLAST-covered Subset")
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0)
plt.tight_layout()
plt.show()
# Out:
# Counts — Pantheon+SH0ES all: 1701, BLAST subset: 543

# %% [markdown]
# ## ZTF ##

# %%
PANTHEON_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/Pantheon+SH0ES.csv"
BLAST_SHOES_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/explore_webapi_with_blast_only_SHOES.csv"

# Load CSVs
pantheon = pd.read_csv(PANTHEON_CSV)
blast_shoes = pd.read_csv(BLAST_SHOES_CSV)

# Extract redshifts
z_all_pantheon = pd.to_numeric(pantheon["zHEL"], errors="coerce").dropna().to_numpy()
z_blast_subset = pd.to_numeric(blast_shoes["zHEL"], errors="coerce").dropna().to_numpy()

print(f"Counts — Pantheon+SH0ES all: {z_all_pantheon.size}, BLAST subset: {z_blast_subset.size}")

# Shared binning (explicit control here!)
zmin, zmax = min(z_all_pantheon.min(), z_blast_subset.min()), \
             max(z_all_pantheon.max(), z_blast_subset.max())
bins = np.linspace(zmin, zmax, 150)   # adjust number of bins here

# Plot
plt.figure(figsize=(12, 6))
plt.hist(z_all_pantheon, bins=bins, alpha=0.3, label="Pantheon+SH0ES SNe Ia (zHEL)", color="red", log=True)
plt.hist(z_blast_subset, bins=bins, alpha=0.8, label="BLAST-covered Pantheon+SH0ES (zHEL)", color="black", log=True)

plt.xlabel("Redshift z")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# Counts — Pantheon+SH0ES all: 1701, BLAST subset: 543

# %%
# Load your CSV
csv_path = "ZTF_snia_data.csv"
df = pd.read_csv(csv_path)

missing_from_blast = []


# Make a function to fetch BLAST info for one SN
def get_blast_info(sn_name):
    url = f"https://blast.ncsa.illinois.edu/api/transient/get/{sn_name}?format=json"
    try:
        with urlopen(url) as r:
            payload = json.loads(r.read())
    except Exception as e:
        print(f"Error fetching {sn_name}: {e}")
        missing_from_blast.append(sn_name)   # keep track of failures
        return {}

    row = {
        "blast_transient_spectroscopic_class": (payload.get("transient_spectroscopic_class") or "").strip(),
        "blast_transient_photometric_class": (payload.get("transient_photometric_class") or "").strip(),
        
        "blast_host_name": payload.get("host_name"),
        "blast_host_ra_deg": payload.get("host_ra_deg"),
        "blast_host_dec_deg": payload.get("host_dec_deg"),
        "blast_host_redshift": payload.get("host_redshift"),
        "blast_host_EBV_MW": payload.get("host_milkyway_dust_reddening"),

        # Local SED
        "blast_local_log_mass_50": payload.get("local_aperture_host_log_mass_50"),
        "blast_local_log_sfr_50": payload.get("local_aperture_host_log_sfr_50"),
        "blast_local_log_ssfr_50": payload.get("local_aperture_host_log_ssfr_50"),
        "blast_local_log_age_50": payload.get("local_aperture_host_log_age_50"),
        "blast_local_mass_surviving_ratio": payload.get("local_aperture_host_mass_surviving_ratio"),

        # Global SED
        "blast_global_log_mass_50": payload.get("global_aperture_host_log_mass_50"),
        "blast_global_log_sfr_50": payload.get("global_aperture_host_log_sfr_50"),
        "blast_global_log_ssfr_50": payload.get("global_aperture_host_log_ssfr_50"),
        "blast_global_log_age_50": payload.get("global_aperture_host_log_age_50"),
        "blast_global_mass_surviving_ratio": payload.get("global_aperture_host_mass_surviving_ratio"),
    }
    return row

# Apply to each SN in your CSV (assuming column is "CID" or "SNID")
blast_rows = []
for sn in df["iau_name"]:
    blast_rows.append(get_blast_info(sn))

# Merge the results back into your DataFrame
blast_df = pd.DataFrame(blast_rows)
df = pd.concat([df, blast_df], axis=1)

# Save to new file
df.to_csv("explore_webapi_with_blast_SHOES.csv", index=False)
print(missing_from_blast)
# Out:
# Error fetching 2018lq: HTTP Error 404: Not Found
# Error fetching 2018kc: HTTP Error 404: Not Found
# Error fetching 2018xi: HTTP Error 404: Not Found
# Error fetching 2020chl: HTTP Error 404: Not Found
# Error fetching 2018aey: HTTP Error 404: Not Found
# Error fetching 2018aic: HTTP Error 404: Not Found
# Error fetching 2018abj: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018aii: HTTP Error 404: Not Found
# Error fetching 2018aab: HTTP Error 404: Not Found
# Error fetching 2020biz: HTTP Error 404: Not Found
# Error fetching 2019abh: HTTP Error 404: Not Found
# Error fetching 2018aej: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018zp: HTTP Error 404: Not Found
# Error fetching 2018bav: HTTP Error 404: Not Found
# Error fetching 2018bat: HTTP Error 404: Not Found
# Error fetching 2018aqy: HTTP Error 404: Not Found
# Error fetching 2018loy: HTTP Error 404: Not Found
# Error fetching 2018ast: HTTP Error 404: Not Found
# Error fetching 2018bau: HTTP Error 404: Not Found
# Error fetching 2018loz: HTTP Error 404: Not Found
# Error fetching 2018avg: HTTP Error 404: Not Found
# Error fetching 2018asj: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018auv: HTTP Error 404: Not Found
# Error fetching 2018ats: HTTP Error 404: Not Found
# Error fetching 2018bba: HTTP Error 404: Not Found
# Error fetching 2018lpa: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019cdd: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018zc: HTTP Error 404: Not Found
# Error fetching 2018baw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018ebo: HTTP Error 404: Not Found
# Error fetching 2018bay: HTTP Error 404: Not Found
# Error fetching 2018baq: HTTP Error 404: Not Found
# Error fetching 2020acqt: HTTP Error 404: Not Found
# Error fetching 2018awa: HTTP Error 404: Not Found
# Error fetching 2018bax: HTTP Error 404: Not Found
# Error fetching 2018bcp: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2
# Error fetching 2018ktx: HTTP Error 404: Not Found
# Error fetching 2018kyb: HTTP Error 404: Not Found
# Error fetching 2018jpr: HTTP Error 404: Not Found
# Error fetching 2018ldi: HTTP Error 404: Not Found
# Error fetching 2018kwq: HTTP Error 404: Not Found
# Error fetching 2018knf: HTTP Error 404: Not Found
# Error fetching 2019ga: HTTP Error 404: Not Found
# Error fetching 2018jqp: HTTP Error 404: Not Found
# Error fetching 2018ldk: HTTP Error 404: Not Found
# Error fetching 2018lfb: HTTP Error 404: Not Found
# Error fetching 2018ldz: HTTP Error 404: Not Found
# Error fetching 2018lla: HTTP Error 404: Not Found
# Error fetching 2018lak: HTTP Error 404: Not Found
# Error fetching 2018kxo: HTTP Error 404: Not Found
# Error fetching 2018lef: HTTP Error 404: Not Found
# Error fetching 2018ldq: HTTP Error 404: Not Found
# Error fetching 2018ati: HTTP Error 404: Not Found
# Error fetching 2018lbi: HTTP Error 404: Not Found
# Error fetching 2018ldw: HTTP Error 404: Not Found
# Error fetching 2018kzc: HTTP Error 404: Not Found
# Error fetching 2018hnl: HTTP Error 404: Not Found
# Error fetching 2018lhw: HTTP Error 404: Not Found
# Error fetching 2019bt: HTTP Error 404: Not Found
# Error fetching 2019gj: HTTP Error 404: Not Found
# Error fetching 2020boc: HTTP Error 404: Not Found
# Error fetching 2019ir: HTTP Error 404: Not Found
# Error fetching 2019gm: HTTP Error 404: Not Found
# Error fetching 2019go: HTTP Error 404: Not Found
# Error fetching 2019qj: HTTP Error 404: Not Found
# Error fetching 2019fp: HTTP Error 404: Not Found
# Error fetching 2019gf: HTTP Error 404: Not Found
# Error fetching 2018alh: HTTP Error 404: Not Found
# Error fetching 2018gsv: HTTP Error 404: Not Found
# Error fetching 2019qb: HTTP Error 404: Not Found
# Error fetching 2019qo: HTTP Error 404: Not Found
# Error fetching 2019ri: HTTP Error 404: Not Found
# Error fetching 2019oc: HTTP Error 404: Not Found
# Error fetching 2019qc: HTTP Error 404: Not Found
# Error fetching 2019qe: HTTP Error 404: Not Found
# Error fetching 2019sw: HTTP Error 404: Not Found
# Error fetching 2019ajc: HTTP Error 404: Not Found
# Error fetching 2019rg: HTTP Error 404: Not Found
# Error fetching 2019qr: HTTP Error 404: Not Found
# Error fetching 2019bly: HTTP Error 404: Not Found
# Error fetching 2019xj: HTTP Error 404: Not Found
# Error fetching 2019ww: HTTP Error 404: Not Found
# Error fetching 2019ahj: HTTP Error 404: Not Found
# Error fetching 2019abf: HTTP Error 404: Not Found
# Error fetching 2019abv: HTTP Error 404: Not Found
# Error fetching 2019ajb: HTTP Error 404: Not Found
# Error fetching 2019afa: HTTP Error 404: Not Found
# Error fetching 2019bac: HTTP Error 404: Not Found
# Error fetching 2019abk: HTTP Error 404: Not Found
# Error fetching 2019abg: HTTP Error 404: Not Found
# Error fetching 2019agi: HTTP Error 404: Not Found
# Error fetching 2019akk: HTTP Error 404: Not Found
# Error fetching 2019anw: HTTP Error 404: Not Found
# Error fetching 2019ajd: HTTP Error 404: Not Found
# Error fetching 2019aof: HTTP Error 404: Not Found
# Error fetching 2019ago: HTTP Error 404: Not Found
# Error fetching 2019agr: HTTP Error 404: Not Found
# Error fetching 2019wis: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020jfl: HTTP Error 404: Not Found
# Error fetching 2019akf: HTTP Error 404: Not Found
# Error fetching 2019arb: HTTP Error 404: Not Found
# Error fetching 2019bge: HTTP Error 404: Not Found
# Error fetching 2019aux: HTTP Error 404: Not Found
# Error fetching 2019avh: HTTP Error 404: Not Found
# Error fetching 2019avi: HTTP Error 404: Not Found
# Error fetching 2019arf: HTTP Error 404: Not Found
# Error fetching 2019avn: HTTP Error 404: Not Found
# Error fetching 2019aqz: HTTP Error 404: Not Found
# Error fetching 2019ari: HTTP Error 404: Not Found
# Error fetching 2019avp: HTTP Error 404: Not Found
# Error fetching 2019amp: HTTP Error 404: Not Found
# Error fetching 2019ana: HTTP Error 404: Not Found
# Error fetching 2019aqm: HTTP Error 404: Not Found
# Error fetching 2019bhe: HTTP Error 404: Not Found
# Error fetching 2019aki: HTTP Error 404: Not Found
# Error fetching 2019bgf: HTTP Error 404: Not Found
# Error fetching 2019axj: HTTP Error 404: Not Found
# Error fetching 2019aup: HTTP Error 404: Not Found
# Error fetching 2019bek: HTTP Error 404: Not Found
# Error fetching 2019blu: HTTP Error 404: Not Found
# Error fetching 2019awi: HTTP Error 404: Not Found
# Error fetching 2019avy: HTTP Error 404: Not Found
# Error fetching 2019bgk: HTTP Error 404: Not Found
# Error fetching 2019ayb: HTTP Error 404: Not Found
# Error fetching 2019bgg: HTTP Error 404: Not Found
# Error fetching 2019azs: HTTP Error 404: Not Found
# Error fetching 2019baj: HTTP Error 404: Not Found
# Error fetching 2019aze: HTTP Error 404: Not Found
# Error fetching 2020ctr: HTTP Error 404: Not Found
# Error fetching 2019bam: HTTP Error 404: Not Found
# Error fetching 2019blt: HTTP Error 404: Not Found
# Error fetching 2019bdg: HTTP Error 404: Not Found
# Error fetching 2019bik: HTTP Error 404: Not Found
# Error fetching 2019big: HTTP Error 404: Not Found
# Error fetching 2019beo: HTTP Error 404: Not Found
# Error fetching 2019bdh: HTTP Error 404: Not Found
# Error fetching 2019bar: HTTP Error 404: Not Found
# Error fetching 2019bau: HTTP Error 404: Not Found
# Error fetching 2019bvn: HTTP Error 404: Not Found
# Error fetching 2019bbc: HTTP Error 404: Not Found
# Error fetching 2019bbe: HTTP Error 404: Not Found
# Error fetching 2019bnu: HTTP Error 404: Not Found
# Error fetching 2019bjp: HTTP Error 404: Not Found
# Error fetching 2019bnx: HTTP Error 404: Not Found
# Error fetching 2019bdk: HTTP Error 404: Not Found
# Error fetching 2019bis: HTTP Error 404: Not Found
# Error fetching 2019bkf: HTTP Error 404: Not Found
# Error fetching 2019blf: HTTP Error 404: Not Found
# Error fetching 2019bys: HTTP Error 404: Not Found
# Error fetching 2019bev: HTTP Error 404: Not Found
# Error fetching 2019bfj: HTTP Error 404: Not Found
# Error fetching 2019bow: HTTP Error 404: Not Found
# Error fetching 2019bqz: HTTP Error 404: Not Found
# Error fetching 2019bij: HTTP Error 404: Not Found
# Error fetching 2019bit: HTTP Error 404: Not Found
# Error fetching 2019azr: HTTP Error 404: Not Found
# Error fetching 2019btt: HTTP Error 404: Not Found
# Error fetching 2019bpf: HTTP Error 404: Not Found
# Error fetching 2019byc: HTTP Error 404: Not Found
# Error fetching 2019bon: HTTP Error 404: Not Found
# Error fetching 2019btu: HTTP Error 404: Not Found
# Error fetching 2019cat: HTTP Error 404: Not Found
# Error fetching 2019brb: HTTP Error 404: Not Found
# Error fetching 2019bor: HTTP Error 404: Not Found
# Error fetching 2019bpe: HTTP Error 404: Not Found
# Error fetching 2019bou: HTTP Error 404: Not Found
# Error fetching 2019bth: HTTP Error 404: Not Found
# Error fetching 2019btg: HTTP Error 404: Not Found
# Error fetching 2020aewj: HTTP Error 404: Not Found
# Error fetching 2019boj: HTTP Error 404: Not Found
# Error fetching 2019blp: HTTP Error 404: Not Found
# Error fetching 2019bua: HTTP Error 404: Not Found
# Error fetching 2019brc: HTTP Error 404: Not Found
# Error fetching 2019bvq: HTTP Error 404: Not Found
# Error fetching 2019bye: HTTP Error 404: Not Found
# Error fetching 2019byv: HTTP Error 404: Not Found
# Error fetching 2019bss: HTTP Error 404: Not Found
# Error fetching 2019brd: HTTP Error 404: Not Found
# Error fetching 2019ceq: HTTP Error 404: Not Found
# Error fetching 2019bvo: HTTP Error 404: Not Found
# Error fetching 2019bwr: HTTP Error 404: Not Found
# Error fetching 2019bzk: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019cen: HTTP Error 404: Not Found
# Error fetching 2019bxe: HTTP Error 404: Not Found
# Error fetching 2019csl: HTTP Error 404: Not Found
# Error fetching 2019bzp: HTTP Error 404: Not Found
# Error fetching 2019cir: HTTP Error 404: Not Found
# Error fetching 2019cae: HTTP Error 404: Not Found
# Error fetching 2019cdz: HTTP Error 404: Not Found
# Error fetching 2019ctu: HTTP Error 404: Not Found
# Error fetching 2019cea: HTTP Error 404: Not Found
# Error fetching 2019ceb: HTTP Error 404: Not Found
# Error fetching 2019ced: HTTP Error 404: Not Found
# Error fetching 2019cet: HTTP Error 404: Not Found
# Error fetching 2019cmc: HTTP Error 404: Not Found
# Error fetching 2019cnb: HTTP Error 404: Not Found
# Error fetching 2019cmx: HTTP Error 404: Not Found
# Error fetching 2019cew: HTTP Error 404: Not Found
# Error fetching 2019cex: HTTP Error 404: Not Found
# Error fetching 2019cmt: HTTP Error 404: Not Found
# Error fetching 2019cng: HTTP Error 404: Not Found
# Error fetching 2019cjq: HTTP Error 404: Not Found
# Error fetching 2019crb: HTTP Error 404: Not Found
# Error fetching 2019cqd: HTTP Error 404: Not Found
# Error fetching 2019cqe: HTTP Error 404: Not Found
# Error fetching 2019czu: HTTP Error 404: Not Found
# Error fetching 2019cnh: HTTP Error 404: Not Found
# Error fetching 2019cyv: HTTP Error 404: Not Found
# Error fetching 2019crr: HTTP Error 404: Not Found
# Error fetching 2019cvw: HTTP Error 404: Not Found
# Error fetching 2019cnx: HTTP Error 404: Not Found
# Error fetching 2019cyw: HTTP Error 404: Not Found
# Error fetching 2019dat: HTTP Error 404: Not Found
# Error fetching 2019dbi: HTTP Error 404: Not Found
# Error fetching 2019coj: HTTP Error 404: Not Found
# Error fetching 2019ddp: HTTP Error 404: Not Found
# Error fetching 2020pkj: HTTP Error 404: Not Found
# Error fetching 2019cqz: HTTP Error 404: Not Found
# Error fetching 2019czz: HTTP Error 404: Not Found
# Error fetching 2019cxc: HTTP Error 404: Not Found
# Error fetching 2019cyy: HTTP Error 404: Not Found
# Error fetching 2019dac: HTTP Error 404: Not Found
# Error fetching 2019cya: HTTP Error 404: Not Found
# Error fetching 2019cxe: HTTP Error 404: Not Found
# Error fetching 2019dee: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019dgu: HTTP Error 404: Not Found
# Error fetching 2019deg: HTTP Error 404: Not Found
# Error fetching 2019die: HTTP Error 404: Not Found
# Error fetching 2019dfi: HTTP Error 404: Not Found
# Error fetching 2019cza: HTTP Error 404: Not Found
# Error fetching 2019dag: HTTP Error 404: Not Found
# Error fetching 2019cxq: HTTP Error 404: Not Found
# Error fetching 2019dfb: HTTP Error 404: Not Found
# Error fetching 2019dfl: HTTP Error 404: Not Found
# Error fetching 2019cxs: HTTP Error 404: Not Found
# Error fetching 2019cxu: HTTP Error 404: Not Found
# Error fetching 2019dfv: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019dsx: HTTP Error 404: Not Found
# Error fetching 2019dhw: HTTP Error 404: Not Found
# Error fetching 2019cwj: HTTP Error 404: Not Found
# Error fetching 2020pjh: HTTP Error 404: Not Found
# Error fetching 2019dku: HTTP Error 404: Not Found
# Error fetching 2019dkv: HTTP Error 404: Not Found
# Error fetching 2019dml: HTTP Error 404: Not Found
# Error fetching 2019cwl: HTTP Error 404: Not Found
# Error fetching 2019dlh: HTTP Error 404: Not Found
# Error fetching 2019dgb: HTTP Error 404: Not Found
# Error fetching 2019dli: HTTP Error 404: Not Found
# Error fetching 2019dxp: HTTP Error 404: Not Found
# Error fetching 2019dom: HTTP Error 404: Not Found
# Error fetching 2019drc: HTTP Error 404: Not Found
# Error fetching 2018axx: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019dpx: HTTP Error 404: Not Found
# Error fetching 2019duu: HTTP Error 404: Not Found
# Error fetching 2019drk: HTTP Error 404: Not Found
# Error fetching 2019eqk: HTTP Error 404: Not Found
# Error fetching 2019dsn: HTTP Error 404: Not Found
# Error fetching 2019duf: HTTP Error 404: Not Found
# Error fetching 2019dpw: HTTP Error 404: Not Found
# Error fetching 2019duk: HTTP Error 404: Not Found
# Error fetching 2019dtb: HTTP Error 404: Not Found
# Error fetching 2019duj: HTTP Error 404: Not Found
# Error fetching 2019edu: HTTP Error 404: Not Found
# Error fetching 2019dwp: HTTP Error 404: Not Found
# Error fetching 2019dwr: HTTP Error 404: Not Found
# Error fetching 2019dwu: HTTP Error 404: Not Found
# Error fetching 2019eef: HTTP Error 404: Not Found
# Error fetching 2019eib: HTTP Error 404: Not Found
# Error fetching 2019eks: HTTP Error 404: Not Found
# Error fetching 2019eqh: HTTP Error 404: Not Found
# Error fetching 2019eid: HTTP Error 404: Not Found
# Error fetching 2019enn: HTTP Error 404: Not Found
# Error fetching 2019eoc: HTTP Error 404: Not Found
# Error fetching 2019eod: HTTP Error 404: Not Found
# Error fetching 2019enu: HTTP Error 404: Not Found
# Error fetching 2019eiq: HTTP Error 404: Not Found
# Error fetching 2019eke: HTTP Error 404: Not Found
# Error fetching 2019fbw: HTTP Error 404: Not Found
# Error fetching 2019ewi: HTTP Error 404: Not Found
# Error fetching 2019etn: HTTP Error 404: Not Found
# Error fetching 2019elg: HTTP Error 404: Not Found
# Error fetching 2019ell: HTTP Error 404: Not Found
# Error fetching 2019elm: HTTP Error 404: Not Found
# Error fetching 2019fkp: HTTP Error 404: Not Found
# Error fetching 2019enp: HTTP Error 404: Not Found
# Error fetching 2019fkf: HTTP Error 404: Not Found
# Error fetching 2019evf: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019fcq: HTTP Error 404: Not Found
# Error fetching 2019fch: HTTP Error 404: Not Found
# Error fetching 2019fcm: HTTP Error 404: Not Found
# Error fetching 2019faq: HTTP Error 404: Not Found
# Error fetching 2019ewz: HTTP Error 404: Not Found
# Error fetching 2019fjt: HTTP Error 404: Not Found
# Error fetching 2019flf: HTTP Error 404: Not Found
# Error fetching 2019fju: HTTP Error 404: Not Found
# Error fetching 2019gcg: HTTP Error 404: Not Found
# Error fetching 2019fer: HTTP Error 404: Not Found
# Error fetching 2019fcp: HTTP Error 404: Not Found
# Error fetching 2019fyf: HTTP Error 404: Not Found
# Error fetching 2019fet: HTTP Error 404: Not Found
# Error fetching 2019fil: HTTP Error 404: Not Found
# Error fetching 2019fxs: HTTP Error 404: Not Found
# Error fetching 2019gqx: HTTP Error 404: Not Found
# Error fetching 2019gct: HTTP Error 404: Not Found
# Error fetching 2019gvj: HTTP Error 404: Not Found
# Error fetching 2019gcu: HTTP Error 404: Not Found
# Error fetching 2019gcm: HTTP Error 404: Not Found
# Error fetching 2019gbq: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019fmc: HTTP Error 404: Not Found
# Error fetching 2019giu: HTTP Error 404: Not Found
# Error fetching 2019gsw: HTTP Error 404: Not Found
# Error fetching 2019gjq: HTTP Error 404: Not Found
# Error fetching 2019gme: HTTP Error 404: Not Found
# ...
# Error fetching 2020whs: HTTP Error 404: Not Found
# Error fetching 2020wtp: HTTP Error 404: Not Found
# Error fetching 2020xyj: HTTP Error 404: Not Found
# Error fetching 2020xtq: HTTP Error 404: Not Found
# Error fetching 2020wze: HTTP Error 404: Not Found
# Error fetching 2020xne: HTTP Error 404: Not Found
# Error fetching 2020wop: HTTP Error 404: Not Found
# Error fetching 2020xba: HTTP Error 404: Not Found
# Error fetching 2020xlk: HTTP Error 404: Not Found
# Error fetching 2020xky: HTTP Error 404: Not Found
# Error fetching 2020wza: HTTP Error 404: Not Found
# Error fetching 2020ygy: HTTP Error 404: Not Found
# Error fetching 2020xsx: HTTP Error 404: Not Found
# Error fetching 2020xsr: HTTP Error 404: Not Found
# Error fetching 2020xqb: HTTP Error 404: Not Found
# Error fetching 2020xyd: HTTP Error 404: Not Found
# Error fetching 2020xit: HTTP Error 404: Not Found
# Error fetching 2020yep: HTTP Error 404: Not Found
# Error fetching 2020ypm: HTTP Error 404: Not Found
# Error fetching 2020xif: HTTP Error 404: Not Found
# Error fetching 2020acmn: HTTP Error 404: Not Found
# Error fetching 2020acmf: HTTP Error 404: Not Found
# Error fetching 2020acod: HTTP Error 404: Not Found
# Error fetching 2020acol: HTTP Error 404: Not Found
# Error fetching 2020acpb: HTTP Error 404: Not Found
# Error fetching 2020acwj: HTTP Error 404: Not Found
# Error fetching 2020acsn: HTTP Error 404: Not Found
# Error fetching 2020adbx: HTTP Error 404: Not Found
# Error fetching 2020adgj: HTTP Error 404: Not Found
# Error fetching 2020adbk: HTTP Error 404: Not Found
# Error fetching 2020adkp: HTTP Error 404: Not Found
# Error fetching 2020actp: HTTP Error 404: Not Found
# Error fetching 2020acrr: HTTP Error 404: Not Found
# Error fetching 2020adle: HTTP Error 404: Not Found
# Error fetching 2020acwp: HTTP Error 404: Not Found
# Error fetching 2020acvz: HTTP Error 404: Not Found
# Error fetching 2020acwt: HTTP Error 404: Not Found
# Error fetching 2020adca: HTTP Error 404: Not Found
# Error fetching 2020adcp: HTTP Error 404: Not Found
# Error fetching 2020adcb: HTTP Error 404: Not Found
# Error fetching 2020aden: HTTP Error 404: Not Found
# Error fetching 2020adeq: HTTP Error 404: Not Found
# Error fetching 2020adfb: HTTP Error 404: Not Found
# Error fetching 2020uyh: HTTP Error 404: Not Found
# Error fetching 2020adeu: HTTP Error 404: Not Found
# Error fetching 2020aepp: HTTP Error 404: Not Found
# Error fetching 2020aeuh: HTTP Error 404: Not Found
# Error fetching 2020adka: HTTP Error 404: Not Found
# Error fetching 2020adij: HTTP Error 404: Not Found
# Error fetching 2020adhi: HTTP Error 404: Not Found
# Error fetching 2020abla: HTTP Error 404: Not Found
# Error fetching 2020aejg: HTTP Error 404: Not Found
# Error fetching 2020adqq: HTTP Error 404: Not Found
# Error fetching 2020adqu: HTTP Error 404: Not Found
# Error fetching 2020aett: HTTP Error 404: Not Found
# Error fetching 2020adra: HTTP Error 404: Not Found
# Error fetching 2020advm: HTTP Error 404: Not Found
# Error fetching 2020aerf: HTTP Error 404: Not Found
# Error fetching 2020dcn: HTTP Error 404: Not Found
# Error fetching 2020cro: HTTP Error 404: Not Found
# Error fetching 2020dcm: HTTP Error 404: Not Found
# Error fetching 2020daw: HTTP Error 404: Not Found
# Error fetching 2018kv: HTTP Error 404: Not Found
# Error fetching 2018kmy: HTTP Error 404: Not Found
# ['2018lq', '2018kc', '2018xi', '2020chl', '2018aey', '2018aic', '2018abj', nan, '2018aii', '2018aab', '2020biz', '2019abh', '2018aej', nan, '2018zp', '2018bav', '2018bat', '2018aqy', '2018loy', '2018ast', '2018bau', '2018loz', '2018avg', '2018asj', nan, '2018auv', '2018ats', '2018bba', '2018lpa', nan, nan, '2019cdd', nan, '2018zc', '2018baw', nan, '2018ebo', '2018bay', '2018baq', '2020acqt', '2018awa', '2018bax', '2018bcp', nan, '2019zbj', '2020gaa', nan, '2018atr', '2018bfx', nan, '2018bbz', nan, nan, '2018cad', '2018aws', '2020fqi', '2018bgp', '2019wnr', '2018adj', '2018bcm', '2018bbn', '2018awj', '2018zs', '2018bcz', '2018hvr', '2020jbl', '2018
fdy', '2018fhg', '2018ffi', nan, nan, '2018fjv', '2018fin', '2018fhh', '2018evd', '2018fjx', '2018evf', '2018fem', '2018fiv', nan, nan, '2018lpl', '2018fja', '2018fmr', nan, '2018emf', '2018foc', '2018lpx', '2018flg', '2018fst', '2018fnc', '2018fpi', '2018erc', '2018fmu', '2018fte', '2018ftd', '2018fod', nan, '2018fqe', '2018ffo', '2018fnd', '2018fse', '2018fwf', '2018lpy', '2018fpv', '2018fpe', '2018fsf', '2018lqy', '2018fry', nan, '2018geu', '2018fnf', '2018fss', '2018fsr', '2018fsq', nan, '2018ftt', '2018gcg', '2018gem', '2018ful', nan, '2018gqe', '2018fqj', '2018frx', nan, '2018gfs', '2018fuu', '2018fty', '2018ftu', nan, '2018gfg', '2018gck', '2018lpn', '2018fvw', '2018ghp', '2018fum', nan, '2018lpo', '2018fvl', nan, '2018gfe', '2018fqk', ' ...

# %%
import pandas as pd

csv_in  = "explore_webapi_with_blast_ZTF.csv"
csv_out = "explore_webapi_with_blast_only_ZTF.csv"
csv_missing = "missing_from_blast_ZTF.csv"

# Load
df = pd.read_csv(csv_in)

# All BLAST columns (those we added with the 'blast_' prefix)
blast_cols = [c for c in df.columns if c.startswith("blast_")]

# Mark rows that have at least ONE non-null BLAST value
has_blast = df[blast_cols].notna().any(axis=1)

# Keep only rows with BLAST info
kept = df[has_blast].copy()

# Rows removed = missing from BLAST entirely
missing = df[~has_blast].copy()

# (Optional) pick a likely name/ID column to show in the missing file
name_col = next((c for c in ["CID", "SNID", "transient_name"] if c in df.columns), None)
if name_col:
    missing = missing[[name_col] + blast_cols]  # show identifier + the empty blast columns

# Save results
kept.to_csv(csv_out, index=False)
missing.to_csv(csv_missing, index=False)

print(f"Kept {len(kept)} rows with BLAST data → {csv_out}")
print(f"Removed {len(missing)} rows missing BLAST data → {csv_missing}")
# Out:
# Kept 1018 rows with BLAST data → explore_webapi_with_blast_only_ZTF.csv
# Removed 2610 rows missing BLAST data → missing_from_blast_ZTF.csv

# %%
# Paths
ZTF_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/ZTF_snia_data.csv"
BLAST_ZTF_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/explore_webapi_with_blast_only_ZTF.csv"

# Load CSVs
ztf = pd.read_csv(ZTF_CSV)
blast_ztf = pd.read_csv(BLAST_ZTF_CSV)

# Extract redshifts (ZTF uses 'redshift')
z_all_ztf    = pd.to_numeric(ztf["redshift"], errors="coerce").dropna().to_numpy()
z_blast_ztf  = pd.to_numeric(blast_ztf["redshift"], errors="coerce").dropna().to_numpy()

print(f"Counts — ZTF all: {z_all_ztf.size}, BLAST-covered ZTF: {z_blast_ztf.size}")

# Shared binning — you control it here
zmin, zmax = min(z_all_ztf.min(), z_blast_ztf.min()), max(z_all_ztf.max(), z_blast_ztf.max())
bins = np.linspace(zmin, zmax, 100)   # adjust # of bins as you like

# Plot
plt.figure(figsize=(12, 6))
plt.hist(z_all_ztf,   bins=bins, alpha=0.3, label="ZTF SNe Ia (redshift)", color="red")
plt.hist(z_blast_ztf, bins=bins, alpha=0.8, label="BLAST-covered ZTF (redshift)", color="black")

plt.xlabel("Redshift z")
plt.ylabel("Count")
plt.title("Redshift Distributions: ZTF vs BLAST-covered ZTF Subset")
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0)
plt.tight_layout()
plt.show()
# Out:
# Counts — ZTF all: 3628, BLAST-covered ZTF: 1018

# %%
# Paths
ZTF_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/ZTF_snia_data.csv"
BLAST_ZTF_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/explore_webapi_with_blast_only_ZTF.csv"

# Load CSVs
ztf = pd.read_csv(ZTF_CSV)
blast_ztf = pd.read_csv(BLAST_ZTF_CSV)

# Extract redshifts (ZTF uses 'redshift')
z_all_ztf    = pd.to_numeric(ztf["redshift"], errors="coerce").dropna().to_numpy()
z_blast_ztf  = pd.to_numeric(blast_ztf["redshift"], errors="coerce").dropna().to_numpy()

print(f"Counts — ZTF all: {z_all_ztf.size}, BLAST-covered ZTF: {z_blast_ztf.size}")

# Shared binning — you control it here
zmin, zmax = min(z_all_ztf.min(), z_blast_ztf.min()), max(z_all_ztf.max(), z_blast_ztf.max())
bins = np.linspace(zmin, zmax, 100)   # adjust # of bins as you like

# Plot
plt.figure(figsize=(12, 6))
plt.hist(z_all_ztf,   bins=bins, alpha=0.3, label="ZTF SNe Ia (redshift)", color="red")
plt.hist(z_blast_ztf, bins=bins, alpha=0.8, label="BLAST-covered ZTF (redshift)", color="black")

plt.xlabel("Redshift z")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# Counts — ZTF all: 3628, BLAST-covered ZTF: 1018

# %%
import pandas as pd

# Read CSV
df = pd.read_csv("data/DES_BLAST_missing.csv")

# Drop empty rows and NaNs in the CID column
names = df["CID"].dropna().astype(str).str.strip()
names = names[names != ""]  # remove blank strings

# Print each name on a new line
for name in names:
    print(name)
# Out:
# 2001ah
# 2001ay
# 2001eh
# 2002he
# 2002hu
# 2003fa
# 2003iv
# 2005ms
# 2006S
# 2006az
# 2006cf
# 2006oa
# 2006on
# 2006qo
# 2007R
# 2007sw
# 2008050
# 2008051
# 2010dt
# AT2016ews
# AT2017po
# ATLAS17ajn
# CSS160129
# PS15asb
# PS15brr
# PS15bwh
# PS15cwx
# PS16ayd
# PS16cqa
# PS16em
# SN2016aqb
# SN2016glp
# SN2016hhv

# %%
import pandas as pd

# Read CSV
df = pd.read_csv("missing_from_blast_SHOES.csv")

# Drop empty rows and NaNs in the CID column
names = df["CID"].dropna().astype(str).str.strip()
names = names[names != ""]  # remove blank strings

# Save to a text file, one per line
with open("SNIa_missing_SHOES.txt", "w") as f:
    for name in names:
        f.write(name + "\n")

# %%
import pandas as pd

# Read CSV
df = pd.read_csv("missing_from_blast_ZTF.csv")

# Drop empty rows and NaNs in the iau_name column
names = df["iau_name"].dropna().astype(str).str.strip()
names = names[names != ""]

# Add SN prefix (avoid duplicating if already present)
names_prefixed = names.apply(lambda n: n if n.startswith("SN") else "SN" + n)

# Save to a text file, one per line
with open("SNIa_missing_ZTF.txt", "w") as f:
    for name in names_prefixed:
        f.write(name + "\n")
