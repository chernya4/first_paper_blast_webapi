# %%
from urllib.request import urlopen
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from collections import defaultdict

# %% [markdown]
# ## Function that allows us to automate calls to the API so that we can extract data fro Large Data Sets ##

# %%
def get_blast_info(sn_name):
    """
    Fetch information for a supernova/transient from the BLAST API.

    Parameters
    ----------
    sn_name : str
        The supernova/transient name (e.g. "2004ef").

    Returns
    -------
    tuple
        (row_dict, missing_name_or_None)
        - On success: (dict of BLAST fields, None)
        - On failure: ({}, sn_name)
    """

    url = f"https://blast.ncsa.illinois.edu/api/transient/get/{sn_name}?format=json"
    try:
        with urlopen(url) as r:
            payload = json.loads(r.read())
    
    ## The following catches any Python Exception that happened within the "try" block.
    ## Error object gets stored as the variable e.
    ## Also keeps track of missing supernova names. Upon exceptions being thrown, ends up returning just
    ## the string that is the SNIa name. 
    except Exception as e:
        print(f"Error fetching {sn_name}: {e}")
        return {}, sn_name

    row = {
        "blast_transient_spectroscopic_class": (payload.get("transient_spectroscopic_class") or "").strip(),
        "blast_transient_photometric_class": (payload.get("transient_photometric_class") or "").strip(),
        
        "blast_host_name": payload.get("host_name"),
        "blast_host_ra_deg": payload.get("host_ra_deg"),
        "blast_host_dec_deg": payload.get("host_dec_deg"),
        "blast_host_redshift": payload.get("host_redshift"),
        "blast_host_EBV_MW": payload.get("host_milkyway_dust_reddening"),

        # Local SED
        "blast_local_log_mass_50": payload.get("local_aperture_host_log_mass_50"),
        "blast_local_log_sfr_50": payload.get("local_aperture_host_log_sfr_50"),
        "blast_local_log_ssfr_50": payload.get("local_aperture_host_log_ssfr_50"),
        "blast_local_log_age_50": payload.get("local_aperture_host_log_age_50"),
        "blast_local_mass_surviving_ratio": payload.get("local_aperture_host_mass_surviving_ratio"),

        # Global SED
        "blast_global_log_mass_50": payload.get("global_aperture_host_log_mass_50"),
        "blast_global_log_sfr_50": payload.get("global_aperture_host_log_sfr_50"),
        "blast_global_log_ssfr_50": payload.get("global_aperture_host_log_ssfr_50"),
        "blast_global_log_age_50": payload.get("global_aperture_host_log_age_50"),
        "blast_global_mass_surviving_ratio": payload.get("global_aperture_host_mass_surviving_ratio"),
    }
    return row, None

# %% [markdown]
# ## Querying the DES Catalog ##
#
# One of the biggest issues here is

# %%
df = pd.read_csv("data_ZTF/ZTF_snia_data.csv")
df["iau_name"]
# Out:
# 0       2020adv
# 1        2018lq
# 2        2018kc
# 3        2018xi
# 4       2020chl
#          ...
# 3623    2018jnq
# 3624    2018kmy
# 3625    2020xtg
# 3626    2019sfj
# 3627    2020esm
# Name: iau_name, Length: 3628, dtype: object

# %%
# Load your CSV 
csv_path = "data_ZTF/ZTF_snia_data.csv"
df = pd.read_csv(csv_path)

# Collect BLAST info
blast_rows = []
missing_from_blast = []

# Can replace df["CID"] with whatever name df
# has for the IAUA name 
for sn in df["iau_name"]:
    row, missing = get_blast_info(str(sn))  # ensure string format
    blast_rows.append(row)
    if missing:   # missing is sn_name or None
        missing_from_blast.append(missing)

# Merge results back into DataFrame
blast_df = pd.DataFrame(blast_rows)
df = pd.concat([df, blast_df], axis=1)

# Save to new file
df.to_csv("data_ZTF/ZTF_BLAST_QUERY.csv", index=False)

print("Failed lookups:", missing_from_blast)
# Out:
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018aab: HTTP Error 404: Not Found
# Error fetching 2018aej: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018aqy: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019haw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018bff: HTTP Error 404: Not Found
# Error fetching 2018bmv: HTTP Error 404: Not Found
# Error fetching 2018bhr: HTTP Error 404: Not Found
# Error fetching 2018ahq: HTTP Error 404: Not Found
# Error fetching 2018bfk: HTTP Error 404: Not Found
# Error fetching 2018aik: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018ibj: HTTP Error 404: Not Found
# Error fetching 2018bvx: HTTP Error 404: Not Found
# Error fetching 2018bhw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019xax: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018bqo: HTTP Error 404: Not Found
# Error fetching 2018lpd: HTTP Error 404: Not Found
# Error fetching 2019ger: HTTP Error 404: Not Found
# Error fetching 2019rmq: HTTP Error 404: Not Found
# Error fetching 2018lpw: HTTP Error 404: Not Found
# Error fetching 2018cjw: HTTP Error 404: Not Found
# Error fetching 2018bdh: HTTP Error 404: Not Found
# Error fetching 2018cbf: HTTP Error 404: Not Found
# Error fetching 2018btg: HTTP Error 404: Not Found
# Error fetching 2018lpb: HTTP Error 404: Not Found
# Error fetching 2018bzz: HTTP Error 404: Not Found
# Error fetching 2020bjj: HTTP Error 404: Not Found
# Error fetching 2018cbv: HTTP Error 404: Not Found
# Error fetching 2018hqd: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018ced: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018cnx: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018coh: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018cvq: HTTP Error 404: Not Found
# Error fetching 2018cty: HTTP Error 404: Not Found
# Error fetching 2018dyc: HTTP Error 404: Not Found
# Error fetching 2018eps: HTTP Error 404: Not Found
# Error fetching 2018ddg: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018dye: HTTP Error 404: Not Found
# Error fetching 2018dsw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018edw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018lpj: HTTP Error 404: Not Found
# Error fetching 2018crv: HTTP Error 404: Not Found
# Error fetching 2018elh: HTTP Error 404: Not Found
# Error fetching 2018eqa: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fev: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fdz: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fhg: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fiv: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018lpx: HTTP Error 404: Not Found
# Error fetching 2018erc: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fqe: HTTP Error 404: Not Found
# Error fetching 2018fpv: HTTP Error 404: Not Found
# Error fetching 2018fpe: HTTP Error 404: Not Found
# Error fetching 2018fsf: HTTP Error 404: Not Found
# Error fetching 2018lqy: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fsq: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018ful: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fqj: HTTP Error 404: Not Found
# Error fetching 2018frx: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fvw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018lpp: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018grt: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018fay: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018gka: HTTP Error 404: Not Found
# Error fetching 2018git: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018guc: HTTP Error 404: Not Found
# Error fetching 2018erb: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018gqo: HTTP Error 404: Not Found
# Error fetching 2018gqn: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018grb: HTTP Error 404: Not Found
# Error fetching 2018gsq: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018hrm: HTTP Error 404: Not Found
# Error fetching 2018hkn: HTTP Error 404: Not Found
# Error fetching 2018hru: HTTP Error 404: Not Found
# Error fetching 2018hoy: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018iqa: HTTP Error 404: Not Found
# Error fetching 2018ilf: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019exv: HTTP Error 404: Not Found
# Error fetching 2018iuo: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018isf: HTTP Error 404: Not Found
# Error fetching 2018iuc: HTTP Error 404: Not Found
# Error fetching 2018iyw: HTTP Error 404: Not Found
# Error fetching 2018jgx: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2018kbe: HTTP Error 404: Not Found
# Error fetching 2018kie: HTTP Error 404: Not Found
# Error fetching 2018jhv: HTTP Error 404: Not Found
# Error fetching 2018lef: HTTP Error 404: Not Found
# Error fetching 2019qo: HTTP Error 404: Not Found
# Error fetching 2019ri: HTTP Error 404: Not Found
# Error fetching 2019ajc: HTTP Error 404: Not Found
# Error fetching 2019rg: HTTP Error 404: Not Found
# Error fetching 2019qr: HTTP Error 404: Not Found
# Error fetching 2019ww: HTTP Error 404: Not Found
# Error fetching 2019abv: HTTP Error 404: Not Found
# Error fetching 2019afa: HTTP Error 404: Not Found
# Error fetching 2019ago: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020jfl: HTTP Error 404: Not Found
# Error fetching 2019akf: HTTP Error 404: Not Found
# Error fetching 2019avp: HTTP Error 404: Not Found
# Error fetching 2019aup: HTTP Error 404: Not Found
# Error fetching 2020ctr: HTTP Error 404: Not Found
# Error fetching 2019blt: HTTP Error 404: Not Found
# Error fetching 2019bik: HTTP Error 404: Not Found
# Error fetching 2019bnx: HTTP Error 404: Not Found
# Error fetching 2019bpe: HTTP Error 404: Not Found
# Error fetching 2020aewj: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019cnb: HTTP Error 404: Not Found
# Error fetching 2019dat: HTTP Error 404: Not Found
# Error fetching 2019cyy: HTTP Error 404: Not Found
# Error fetching 2019dee: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019dfl: HTTP Error 404: Not Found
# Error fetching 2019cxs: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019eqh: HTTP Error 404: Not Found
# Error fetching 2019ell: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019hax: HTTP Error 404: Not Found
# Error fetching 2019gyz: HTTP Error 404: Not Found
# Error fetching 2019ifp: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019jwp: HTTP Error 404: Not Found
# Error fetching 2019kvn: HTTP Error 404: Not Found
# Error fetching 2019kvl: HTTP Error 404: Not Found
# Error fetching 2019ldl: HTTP Error 404: Not Found
# Error fetching 2019kgw: HTTP Error 404: Not Found
# Error fetching 2019hgv: HTTP Error 404: Not Found
# Error fetching 2019hzv: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019lfh: HTTP Error 404: Not Found
# Error fetching 2019lkt: HTTP Error 404: Not Found
# Error fetching 2019lrr: HTTP Error 404: Not Found
# Error fetching 2019mav: HTTP Error 404: Not Found
# Error fetching 2019mcb: HTTP Error 404: Not Found
# Error fetching 2019mbe: HTTP Error 404: Not Found
# Error fetching 2019mtf: HTTP Error 404: Not Found
# Error fetching 2018cgf: HTTP Error 404: Not Found
# Error fetching 2019mbn: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019mse: HTTP Error 404: Not Found
# Error fetching 2019mon: HTTP Error 404: Not Found
# Error fetching 2019njx: HTTP Error 404: Not Found
# Error fetching 2019mym: HTTP Error 404: Not Found
# Error fetching 2019nql: HTTP Error 404: Not Found
# Error fetching 2019nwl: HTTP Error 404: Not Found
# Error fetching 2019mda: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019ntb: HTTP Error 404: Not Found
# Error fetching 2019olx: HTTP Error 404: Not Found
# Error fetching 2019oly: HTTP Error 404: Not Found
# Error fetching 2019msc: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019oyg: HTTP Error 404: Not Found
# Error fetching 2019ozu: HTTP Error 404: Not Found
# Error fetching 2019pka: HTTP Error 404: Not Found
# Error fetching 2019pmo: HTTP Error 404: Not Found
# Error fetching 2019psk: HTTP Error 404: Not Found
# Error fetching 2019pyd: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019pxe: HTTP Error 404: Not Found
# Error fetching 2019qxs: HTTP Error 404: Not Found
# Error fetching 2019qhm: HTTP Error 404: Not Found
# Error fetching 2019qwi: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019qpn: HTTP Error 404: Not Found
# Error fetching 2019qpr: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019rnm: HTTP Error 404: Not Found
# Error fetching 2019rmb: HTTP Error 404: Not Found
# Error fetching 2019rqb: HTTP Error 404: Not Found
# Error fetching 2018fqc: HTTP Error 404: Not Found
# Error fetching 2019rrc: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019sck: HTTP Error 404: Not Found
# Error fetching 2019shu: HTTP Error 404: Not Found
# Error fetching 2019scw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019sqj: HTTP Error 404: Not Found
# Error fetching 2019sqk: HTTP Error 404: Not Found
# Error fetching 2019suj: HTTP Error 404: Not Found
# Error fetching 2019suc: HTTP Error 404: Not Found
# Error fetching 2019sxm: HTTP Error 404: Not Found
# Error fetching 2019syj: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019tht: HTTP Error 404: Not Found
# Error fetching 2019tiq: HTTP Error 404: Not Found
# Error fetching 2019syw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019tmq: HTTP Error 404: Not Found
# Error fetching 2019ubh: HTTP Error 404: Not Found
# Error fetching 2019tzv: HTTP Error 404: Not Found
# Error fetching 2019tup: HTTP Error 404: Not Found
# Error fetching 2019tns: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019tue: HTTP Error 404: Not Found
# Error fetching 2019aaby: HTTP Error 404: Not Found
# Error fetching 2019uze: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019vbe: HTTP Error 404: Not Found
# Error fetching 2019vuv: HTTP Error 404: Not Found
# Error fetching 2019vmh: HTTP Error 404: Not Found
# Error fetching 2019wce: HTTP Error 404: Not Found
# Error fetching 2019wew: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2019xug: HTTP Error 404: Not Found
# Error fetching 2019yzx: HTTP Error 404: Not Found
# Error fetching 2020ac: HTTP Error 404: Not Found
# Error fetching 2020E: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020kq: HTTP Error 404: Not Found
# Error fetching 2020bj: HTTP Error 404: Not Found
# Error fetching 2019xuj: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020dd: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020hz: HTTP Error 404: Not Found
# Error fetching 2020zk: HTTP Error 404: Not Found
# Error fetching 2020uo: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020py: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020ti: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020xr: HTTP Error 404: Not Found
# Error fetching 2020abu: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020agd: HTTP Error 404: Not Found
# Error fetching 2020apm: HTTP Error 404: Not Found
# Error fetching 2020ahn: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020axo: HTTP Error 404: Not Found
# Error fetching 2020arm: HTTP Error 404: Not Found
# Error fetching 2020bds: HTTP Error 404: Not Found
# Error fetching 2020bdq: HTTP Error 404: Not Found
# Error fetching 2020bbb: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020bec: HTTP Error 404: Not Found
# Error fetching 2020akj: HTTP Error 404: Not Found
# Error fetching 2020blz: HTTP Error 404: Not Found
# Error fetching 2020btv: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020bqm: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020cxe: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020cxo: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020dsn: HTTP Error 404: Not Found
# Error fetching 2020duf: HTTP Error 404: Not Found
# Error fetching 2020exz: HTTP Error 404: Not Found
# Error fetching 2020exu: HTTP Error 404: Not Found
# Error fetching 2020fkg: HTTP Error 404: Not Found
# Error fetching 2020eyf: HTTP Error 404: Not Found
# Error fetching 2020fhk: HTTP Error 404: Not Found
# Error fetching 2020hec: HTTP Error 404: Not Found
# Error fetching 2020gkp: HTTP Error 404: Not Found
# Error fetching 2020hbe: HTTP Error 404: Not Found
# Error fetching 2020hhh: HTTP Error 404: Not Found
# Error fetching 2020hwt: HTTP Error 404: Not Found
# Error fetching 2020iab: HTTP Error 404: Not Found
# Error fetching 2020ipb: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020lvt: HTTP Error 404: Not Found
# Error fetching 2020lwl: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020mpu: HTTP Error 404: Not Found
# Error fetching 2020nia: HTTP Error 404: Not Found
# Error fetching 2020naz: HTTP Error 404: Not Found
# Error fetching 2020oqy: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020nus: HTTP Error 404: Not Found
# Error fetching 2020nqw: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020nxh: HTTP Error 404: Not Found
# Error fetching 2020nze: HTTP Error 404: Not Found
# Error fetching 2020dhg: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020lyt: HTTP Error 404: Not Found
# Error fetching 2020ppd: HTTP Error 404: Not Found
# Error fetching 2020pre: HTTP Error 404: Not Found
# Error fetching 2020qiz: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020qrm: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020rlz: HTTP Error 404: Not Found
# Error fetching 2020qxr: HTTP Error 404: Not Found
# Error fetching 2020ram: HTTP Error 404: Not Found
# Error fetching 2020rod: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020rov: HTTP Error 404: Not Found
# Error fetching 2020rwf: HTTP Error 404: Not Found
# Error fetching 2020rnf: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020sww: HTTP Error 404: Not Found
# Error fetching 2020scd: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020sid: HTTP Error 404: Not Found
# Error fetching 2020sgc: HTTP Error 404: Not Found
# Error fetching 2020sgh: HTTP Error 404: Not Found
# Error fetching 2020spd: HTTP Error 404: Not Found
# Error fetching 2020svi: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020ttg: HTTP Error 404: Not Found
# Error fetching 2020ttf: HTTP Error 404: Not Found
# Error fetching 2020uca: HTTP Error 404: Not Found
# Error fetching 2019olm: HTTP Error 404: Not Found
# Error fetching 2020ule: HTTP Error 404: Not Found
# Error fetching 2020ugv: HTTP Error 404: Not Found
# Error fetching 2020zct: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020vco: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020vaf: HTTP Error 404: Not Found
# Error fetching 2020xvf: HTTP Error 404: Not Found
# Error fetching 2020vfa: HTTP Error 404: Not Found
# Error fetching 2020vee: HTTP Error 404: Not Found
# Error fetching 2020wdq: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020vzm: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020xyj: HTTP Error 404: Not Found
# Error fetching 2020xqq: HTTP Error 404: Not Found
# Error fetching 2020ycp: HTTP Error 404: Not Found
# Error fetching 2020yfc: HTTP Error 404: Not Found
# Error fetching 2020xvc: HTTP Error 404: Not Found
# Error fetching 2020xuv: HTTP Error 404: Not Found
# Error fetching 2020yhg: HTTP Error 404: Not Found
# Error fetching 2020ybt: HTTP Error 404: Not Found
# Error fetching 2020yhn: HTTP Error 404: Not Found
# Error fetching 2020yhj: HTTP Error 404: Not Found
# Error fetching nan: HTTP Error 404: Not Found
# Error fetching 2020ypf: HTTP Error 404: Not Found
# Error fetching 2020yxl: HTTP Error 404: Not Found
# Error fetching 2020yyk: HTTP Error 404: Not Found
# Error fetching 2020yvj: HTTP Error 404: Not Found
# Error fetching 2020ytn: HTTP Error 404: Not Found
# Error fetching 2020yti: HTTP Error 404: Not Found
# Error fetching 2020yvd: HTTP Error 404: Not Found
# Error fetching 2020yzw: HTTP Error 404: Not Found
# Error fetching 2020yuw: HTTP Error 404: Not Found
# Error fetching 2020yvs: HTTP Error 404: Not Found
# Error fetching 2020zgq: HTTP Error 404: Not Found
# Error fetching 2020abog: HTTP Error 404: Not Found
# Error fetching 2020zci: HTTP Error 404: Not Found
# Error fetching 2020aabx: HTTP Error 404: Not Found
# Error fetching 2020zcw: HTTP Error 404: Not Found
# Error fetching 2020aabi: HTTP Error 404: Not Found
# Error fetching 2020zfp: HTTP Error 404: Not Found
# Error fetching 2020zbr: HTTP Error 404: Not Found
# Error fetching 2020zjo: HTTP Error 404: Not Found
# Load
df = pd.read_csv(csv_in)

# All BLAST columns (those we added with the 'blast_' prefix)
blast_cols = [c for c in df.columns if c.startswith("blast_")]

# Mark rows that have at least ONE non-null BLAST value
has_blast = df[blast_cols].notna().any(axis=1)

# Keep only rows with BLAST info
kept = df[has_blast].copy()

# Rows removed = missing from BLAST entirely
missing = df[~has_blast].copy()

# (Optional) pick a likely name/ID column to show in the missing file
name_col = next((c for c in ["CID", "SNID", "transient_name"] if c in df.columns), None)
if name_col:
    missing = missing[[name_col] + blast_cols]  # show identifier + the empty blast columns

# Save results
kept.to_csv(csv_out, index=False)
missing.to_csv(csv_missing, index=False)

print(f"Kept {len(kept)} rows with BLAST data → {csv_out}")
print(f"Removed {len(missing)} rows missing BLAST data → {csv_missing}")
# Out:
# Kept 3158 rows with BLAST data → data_ZTF/ZTF_BLAST_matches.csv
# Removed 470 rows missing BLAST data → data_ZTF/ZTF_BLAST_umatched.csv

# %%
DES_SN_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/data_ZTF/ZTF_snia_data.csv"
BLAST_CSV  = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/data_ZTF/ZTF_BLAST_matches.csv"

# Load
ZTF_sn   = pd.read_csv(DES_SN_CSV)
blast_df = pd.read_csv(BLAST_CSV)

print(len(ZTF_sn), "ZTF SNe Ia total")
matched = len(blast_df)
print(matched, "matched with BLAST data")

z_all_des      = pd.to_numeric(ZTF_sn["redshift"])
z_blast_subset = pd.to_numeric(blast_df["redshift"])

# Shared binning — one line!
zmin = 0
zmax = z_blast_subset.max()
bins = np.linspace(zmin, zmax, 100)   # <-- control bins right here

plt.figure(figsize=(12, 6))
plt.hist(z_all_des,      bins=bins, alpha=0.3, label="ZTF SNe Ia (zHEL)", color = "red")
plt.hist(z_blast_subset, bins=bins, alpha=1, label="BLAST-covered SNe Ia (zHEL)", color = "black")

plt.xlabel("Redshift z")
plt.ylabel("Count")
plt.title("Redshift Distributions: ZTF vs BLAST Subset and BLAST Host z")
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0)
plt.tight_layout()
plt.show()
# Out:
# 3628 ZTF SNe Ia total
# 3158 matched with BLAST data

# %%
DES_SN_CSV = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/data_ZTF/ZTF_snia_data.csv"
BLAST_CSV  = "/Users/pittsburghgraduatestudent/repos/first_paper_blast_webapi/data_ZTF/ZTF_BLAST_matches.csv"

# Load
ZTF_sn   = pd.read_csv(DES_SN_CSV)
blast_df = pd.read_csv(BLAST_CSV)

print(len(ZTF_sn), "ZTF SNe Ia total")
matched = len(blast_df)
print(matched, "matched with BLAST data")

z_all_des      = pd.to_numeric(ZTF_sn["redshift"])
z_blast_subset = pd.to_numeric(blast_df["redshift"])

# Shared binning — one line!
zmin = 0
zmax = z_blast_subset.max()
bins = np.linspace(zmin, zmax, 150)   # <-- control bins right here

plt.figure(figsize=(12, 6))
plt.hist(z_all_des,      bins=bins, alpha=0.3, label="ZTF SNe Ia (zHEL)", color = "red")
plt.hist(z_blast_subset, bins=bins, alpha=1, label="BLAST-covered SNe Ia (zHEL)", color = "black")

plt.xlabel("Redshift z")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# 3628 ZTF SNe Ia total
# 3158 matched with BLAST data
